# %% [markdown]
# # Flight Search Examples with Google Flights API
#
# This notebook demonstrates how to use the Google Flights Search Tool with various search parameters and scenarios using SerpApi.
#
# ## Overview
#
# The Flight Search Tool allows you to:
# - Search for round-trip and one-way flights
# - Specify passenger counts (adults, children, infants)
# - Filter by travel class, price, time preferences
# - Control layover durations
# - Include/exclude specific airlines
# - Enable deep search for more accurate results
#
# Let's explore different examples of how to use this tool!

# %% [markdown]
# ## 1. Import Required Libraries
#
# First, let's import all the necessary libraries including `dotenv` for loading environment variables.

# %% [markdown]
# ## 2. Load Environment Variables with dotenv
#
# We'll use `load_dotenv()` to load the API key from our `.env` file. This is a secure way to manage sensitive credentials.

# %%
# Load environment variables from .env file
load_dotenv()

# Verify that the API key is available
api_key = os.getenv('SERPAPI_API_KEY')
if api_key:
    print("✅ SERPAPI_API_KEY loaded successfully!")
    print(f"API Key preview: {api_key[:10]}...{api_key[-4:]}")
else:
    print("❌ SERPAPI_API_KEY not found. Please check your .env file.")
    print("Make sure you have a .env file with: SERPAPI_API_KEY=your_api_key_here")
# Out:
# ✅ SERPAPI_API_KEY loaded successfully!
# API Key preview: b5c5731600...d58c

# %% [markdown]
# ## Important Note: Directory Structure
#
# Since this notebook is in the `notebooks/` subdirectory and the `flight_search.py` file is in the parent directory (`travel-agent/`), we need to handle the import path correctly.
#
# There are several ways to solve this:
#
# 1. **Path manipulation** (used above): Add the parent directory to Python's path
# 2. **Copy the module**: Create a copy of `flight_search.py` in the notebooks directory
# 3. **Relative imports**: Use relative import syntax
# 4. **Package structure**: Convert the project to a proper Python package
#
# For this notebook, we're using approach #1 and also including the complete implementation to ensure everything works smoothly.

# %% [markdown]
# ## 3. Define the FlightSearcher Class
#
# Now let's define our FlightSearcher class that handles all the flight search functionality using the Google Flights API via SerpApi.

# %%
class FlightSearcher:
    """A class to search for flights using the SerpApi Google Flights API."""
    
    def __init__(self, api_key: str = None):
        """
        Initialize the FlightSearcher.
        
        Args:
            api_key (str): SerpApi API key. If not provided, will try to load from environment.
        """
        self.api_key = api_key or self._load_api_key()
        self.base_url = "https://serpapi.com/search.json"
        
    def _load_api_key(self) -> str:
        """Load API key from environment or .env file."""
        # Load environment variables from .env file
        load_dotenv()
        
        # Try environment variable first
        api_key = os.getenv('SERPAPI_API_KEY')
        if api_key:
            return api_key
                
        raise ValueError("API key not found. Please set SERPAPI_API_KEY in .env file or environment variable.")
    
    def search_flights(self,
                      departure_id: str,
                      arrival_id: str,
                      outbound_date: str,
                      return_date: str = None,
                      trip_type: str = "round_trip",
                      adults: int = 1,
                      children: int = 0,
                      infants: int = 0,
                      travel_class: str = "economy",
                      departure_time_range: str = None,
                      return_time_range: str = None,
                      max_layover_duration: int = None,
                      min_layover_duration: int = None,
                      max_price: int = None,
                      include_airlines: List[str] = None,
                      exclude_airlines: List[str] = None,
                      max_duration: int = None,
                      currency: str = "USD",
                      language: str = "en",
                      country: str = "us",
                      deep_search: bool = False,
                      auto_fetch_return_flights: bool = True) -> Dict:
        """
        Search for flights with specified parameters.
        
        Args:
            departure_id (str): Departure airport code (e.g., 'LAX', 'JFK')
            arrival_id (str): Arrival airport code (e.g., 'LHR', 'CDG')
            outbound_date (str): Departure date in YYYY-MM-DD format
            return_date (str, optional): Return date in YYYY-MM-DD format (required for round trip)
            trip_type (str): 'round_trip', 'one_way', or 'multi_city'
            adults (int): Number of adult passengers (default: 1)
            children (int): Number of child passengers (default: 0)
            infants (int): Number of infant passengers (default: 0)
            travel_class (str): 'economy', 'premium_economy', 'business', or 'first'
            departure_time_range (str): Time range for departure (e.g., '6,12' for 6AM-12PM)
            return_time_range (str): Time range for return flight
            max_layover_duration (int): Maximum layover duration in minutes
            min_layover_duration (int): Minimum layover duration in minutes
            max_price (int): Maximum ticket price
            include_airlines (List[str]): List of airline codes to include
            exclude_airlines (List[str]): List of airline codes to exclude
            max_duration (int): Maximum flight duration in minutes
            currency (str): Currency code (default: 'USD')
            language (str): Language code (default: 'en')
            country (str): Country code (default: 'us')
            deep_search (bool): Enable deep search for more accurate results
            auto_fetch_return_flights (bool): Automatically fetch return flights for round-trip searches
            
        Returns:
            Dict: Flight search results from SerpApi with return flights included for round-trip searches
        """
        
        # Get outbound flights using the single search method
        outbound_results = self._search_flights_single(
            departure_id=departure_id,
            arrival_id=arrival_id,
            outbound_date=outbound_date,
            return_date=return_date,
            trip_type=trip_type,
            adults=adults,
            children=children,
            infants=infants,
            travel_class=travel_class,
            departure_time_range=departure_time_range,
            return_time_range=return_time_range,
            max_layover_duration=max_layover_duration,
            min_layover_duration=min_layover_duration,
            max_price=max_price,
            include_airlines=include_airlines,
            exclude_airlines=exclude_airlines,
            max_duration=max_duration,
            currency=currency,
            language=language,
            country=country,
            deep_search=deep_search
        )
        
        # For round-trip flights, automatically fetch return flights if enabled
        if (trip_type == "round_trip" and auto_fetch_return_flights and 
            not outbound_results.get("error")):
            enhanced_results = self._fetch_complete_round_trip(outbound_results)
            return enhanced_results
        
        return outbound_results
    
    def _search_flights_single(self, **kwargs) -> Dict:
        """Internal method to perform a single flight search API call."""
        # Build the parameters dictionary
        params = {
            "engine": "google_flights",
            "departure_id": kwargs["departure_id"].upper(),
            "arrival_id": kwargs["arrival_id"].upper(),
            "outbound_date": kwargs["outbound_date"],
            "currency": kwargs.get("currency", "USD"),
            "hl": kwargs.get("language", "en"),
            "gl": kwargs.get("country", "us"),
            "api_key": self.api_key
        }
        
        # Set trip type
        type_mapping = {
            "round_trip": 1,
            "one_way": 2,
            "multi_city": 3
        }
        params["type"] = type_mapping.get(kwargs.get("trip_type", "round_trip"), 1)
        
        # Add return date for round trip
        if kwargs.get("trip_type") == "round_trip":
            if not kwargs.get("return_date"):
                raise ValueError("Return date is required for round trip flights")
            params["return_date"] = kwargs["return_date"]
        elif kwargs.get("return_date") and kwargs.get("trip_type") == "one_way":
            print("Warning: Return date specified for one-way trip. Ignoring return date.")
        
        # Set travel class
        class_mapping = {
            "economy": 1,
            "premium_economy": 2,
            "business": 3,
            "first": 4
        }
        params["travel_class"] = class_mapping.get(kwargs.get("travel_class", "economy"), 1)
        
        # Set passenger counts
        if kwargs.get("adults", 1) > 0:
            params["adults"] = kwargs["adults"]
        if kwargs.get("children", 0) > 0:
            params["children"] = kwargs["children"]
        if kwargs.get("infants", 0) > 0:
            params["infants_in_seat"] = kwargs["infants"]
        
        # Set time preferences
        if kwargs.get("departure_time_range"):
            params["outbound_times"] = kwargs["departure_time_range"]
        if kwargs.get("return_time_range") and kwargs.get("trip_type") == "round_trip":
            params["return_times"] = kwargs["return_time_range"]
            
        # Set layover preferences
        if kwargs.get("min_layover_duration") and kwargs.get("max_layover_duration"):
            params["layover_duration"] = f"{kwargs['min_layover_duration']},{kwargs['max_layover_duration']}"
        
        # Set price and duration limits
        if kwargs.get("max_price"):
            params["max_price"] = kwargs["max_price"]
        if kwargs.get("max_duration"):
            params["max_duration"] = kwargs["max_duration"]
            
        # Set airline preferences
        if kwargs.get("include_airlines"):
            params["include_airlines"] = ",".join(kwargs["include_airlines"])
        if kwargs.get("exclude_airlines"):
            params["exclude_airlines"] = ",".join(kwargs["exclude_airlines"])
            
        # Enable deep search if requested
        if kwargs.get("deep_search"):
            params["deep_search"] = "true"
        
        # Make the API request
        try:
            response = requests.get(self.base_url, params=params)
            response.raise_for_status()
            return response.json()
        except requests.exceptions.RequestException as e:
            raise Exception(f"API request failed: {e}")
    
    def _fetch_complete_round_trip(self, outbound_results: Dict) -> Dict:
        """
        Fetch return flights for round-trip searches and combine with outbound flights.
        For each outbound flight, combine with ALL available return flight options.
        """
        all_flights = []
        if outbound_results.get("best_flights"):
            all_flights.extend(outbound_results["best_flights"])
        if outbound_results.get("other_flights"):
            all_flights.extend(outbound_results["other_flights"])
        enhanced_flights = []
        for flight in all_flights:
            if flight.get("departure_token"):
                try:
                    return_results = self._fetch_return_flights(
                        flight["departure_token"],
                        outbound_params=outbound_results.get("search_parameters", {})
                    )
                    combos = self._combine_outbound_all_return_flights(flight, return_results)
                    enhanced_flights.extend(combos)
                except Exception:
                    enhanced_flights.append(flight)
            else:
                enhanced_flights.append(flight)
        enhanced_results = outbound_results.copy()
        num_best = len(outbound_results.get("best_flights", []))
        if num_best > 0:
            enhanced_results["best_flights"] = enhanced_flights[:num_best]
            if len(enhanced_flights) > num_best:
                enhanced_results["other_flights"] = enhanced_flights[num_best:]
        else:
            enhanced_results["other_flights"] = enhanced_flights
        return enhanced_results

    def _fetch_return_flights(self, departure_token: str, outbound_params: dict = None) -> Dict:
        """
        Fetch return flights using a departure token, using multi_city_json and type=3 for round-trip.
        
        Args:
            departure_token (str): Token from outbound flight for fetching return flights
            outbound_params (dict): Original search params for outbound leg (optional, for multi-city_json)
            
        Returns:
            Dict: Return flight search results
        """
        # If outbound_params provided, build multi_city_json for round-trip
        params = {
            "engine": "google_flights",
            "api_key": self.api_key,
            "departure_token": departure_token
        }
        if outbound_params and outbound_params.get("return_date") and outbound_params.get("departure_id") and outbound_params.get("arrival_id"):
            params["type"] = 3
            params["currency"] = outbound_params.get("currency", "USD")
            params["hl"] = outbound_params.get("language", "en")
            # Build multi_city_json for round-trip
            multi_city_json = [
                {"departure_id": outbound_params["departure_id"], "arrival_id": outbound_params["arrival_id"], "date": outbound_params["outbound_date"]},
                {"departure_id": outbound_params["arrival_id"], "arrival_id": outbound_params["departure_id"], "date": outbound_params["return_date"]}
            ]
            import json as _json
            params["multi_city_json"] = _json.dumps(multi_city_json)
        try:
            response = requests.get(self.base_url, params=params)
            response.raise_for_status()
            return response.json()
        except requests.exceptions.HTTPError as e:
            print(f"[ERROR] HTTPError fetching return flights: {e}")
            if e.response is not None:
                print(f"[ERROR] Response content: {e.response.text}")
            raise Exception(f"Return flight API request failed: {e}")
        except requests.exceptions.RequestException as e:
            print(f"[ERROR] RequestException fetching return flights: {e}")
            raise Exception(f"Return flight API request failed: {e}")
    
    def _combine_outbound_return_flights(self, outbound_flight: Dict, return_results: Dict) -> Dict:
        """
        Combine outbound flight with return flight options to create complete round-trip data.
        
        Args:
            outbound_flight (Dict): Outbound flight data
            return_results (Dict): Return flight search results
            
        Returns:
            Dict: Combined flight data with both outbound and return segments
        """
        
        # Start with the outbound flight as base
        combined_flight = outbound_flight.copy()
        
        # Find the best return flight option (first in best_flights or other_flights)
        return_flight = None
        if return_results.get("best_flights"):
            return_flight = return_results["best_flights"][0]
        elif return_results.get("other_flights"):
            return_flight = return_results["other_flights"][0]
        else:
            print("🔧 WARNING: No return flights found in results")
        
        if return_flight and return_flight.get("flights"):
            # Combine the flight segments
            outbound_segments = combined_flight.get("flights", [])
            return_segments = return_flight.get("flights", [])
            
            # Update the combined flight
            combined_flight["flights"] = outbound_segments + return_segments
            
            # Update total duration if both are available
            outbound_duration = combined_flight.get("total_duration", 0)
            return_duration = return_flight.get("total_duration", 0)
            if outbound_duration and return_duration:
                combined_flight["total_duration"] = outbound_duration + return_duration
            
            # Combine layovers
            outbound_layovers = combined_flight.get("layovers", [])
            return_layovers = return_flight.get("layovers", [])
            combined_flight["layovers"] = outbound_layovers + return_layovers
            
            # Add return flight info for debugging
            combined_flight["_return_flight_info"] = {
                "return_price": return_flight.get("price"),
                "return_currency": return_flight.get("currency"),
                "return_duration": return_flight.get("total_duration"),
                "return_segments_count": len(return_segments)
            }
            
        else:
            print("🔧 WARNING: No return flight segments to combine")
        
        return combined_flight
    
    def _combine_outbound_all_return_flights(self, outbound_flight: Dict, return_results: Dict) -> list:
        """
        Combine outbound flight with ALL return flight options to create all possible round-trip combinations.
        Returns a list of combined flights, each with the correct price/currency for that combination.
        """
        combos = []
        return_flights = []
        if return_results.get("best_flights"):
            return_flights.extend(return_results["best_flights"])
        if return_results.get("other_flights"):
            return_flights.extend(return_results["other_flights"])
        if not return_flights:
            print("🔧 WARNING: No return flights found in results (all return options)")
            return [outbound_flight]
        for idx, return_flight in enumerate(return_flights):
            if return_flight.get("flights"):
                combined_flight = outbound_flight.copy()
                outbound_segments = combined_flight.get("flights", [])
                return_segments = return_flight.get("flights", [])
                combined_flight["flights"] = outbound_segments + return_segments
                outbound_duration = combined_flight.get("total_duration", 0)
                return_duration = return_flight.get("total_duration", 0)
                if outbound_duration and return_duration:
                    combined_flight["total_duration"] = outbound_duration + return_duration
                outbound_layovers = combined_flight.get("layovers", [])
                return_layovers = return_flight.get("layovers", [])
                combined_flight["layovers"] = outbound_layovers + return_layovers
                combined_flight["_return_flight_info"] = {
                    "return_price": return_flight.get("price"),
                    "return_currency": return_flight.get("currency"),
                    "return_duration": return_flight.get("total_duration"),
                    "return_segments_count": len(return_segments)
                }
                # Set the price and currency to match the return flight's (which should be the total round-trip price)
                if return_flight.get("price"):
                    combined_flight["price"] = return_flight["price"]
                if return_flight.get("currency"):
                    combined_flight["currency"] = return_flight["currency"]
                # Optionally, mark which return option this is
                combined_flight["_return_option_index"] = idx + 1
                combos.append(combined_flight)
            else:
                combos.append(outbound_flight)
        return combos
    
    def format_flight_results(self, results: Dict) -> str:
        """
        Format flight search results into a readable string with clear separation 
        of outbound and return flights for round-trip searches.
        
        Args:
            results (Dict): Raw API response from flight search
            
        Returns:
            str: Formatted flight information with enhanced round-trip display
        """
        if "error" in results:
            return f"Error: {results['error']}"
        
        output = []
        output.append("=" * 80)
        output.append("✈️  FLIGHT SEARCH RESULTS")
        output.append("=" * 80)
        
        # Search parameters
        if "search_parameters" in results:
            params = results["search_parameters"]
            output.append(f"\n📋 Search Parameters:")
            output.append(f"  Route: {params.get('departure_id', 'N/A')} → {params.get('arrival_id', 'N/A')}")
            output.append(f"  Outbound: {params.get('outbound_date', 'N/A')}")
            if params.get('return_date'):
                output.append(f"  Return: {params.get('return_date', 'N/A')}")
                output.append(f"  Trip Type: Round Trip")
            else:
                output.append(f"  Trip Type: One Way")
            output.append(f"  Currency: {params.get('currency', 'USD')}")
            if params.get('adults', 1) > 1 or params.get('children', 0) > 0 or params.get('infants', 0) > 0:
                passengers = []
                if params.get('adults', 1) > 0:
                    passengers.append(f"{params['adults']} adult(s)")
                if params.get('children', 0) > 0:
                    passengers.append(f"{params['children']} child(ren)")
                if params.get('infants', 0) > 0:
                    passengers.append(f"{params['infants']} infant(s)")
                output.append(f"  Passengers: {', '.join(passengers)}")
        
        # Price insights
        if "price_insights" in results:
            insights = results["price_insights"]
            currency = results.get('search_parameters', {}).get('currency', 'USD')
            output.append(f"\n💰 Price Insights:")
            output.append(f"  Lowest Price: {insights.get('lowest_price', 'N/A')} {currency}")
            output.append(f"  Price Level: {insights.get('price_level', 'N/A')}")
            if insights.get('typical_price_range'):
                low, high = insights['typical_price_range']
                output.append(f"  Typical Range: {low} - {high} {currency}")
        
        # Best flights
        if "best_flights" in results and results["best_flights"]:
            output.append(f"\n{'🌟'*3} BEST FLIGHTS {'🌟'*3}")
            for i, flight in enumerate(results["best_flights"], 1):
                output.append(self._format_single_flight(flight, i))
        
        # Other flights
        if "other_flights" in results and results["other_flights"]:
            output.append(f"\n{'✈️ '*3} OTHER FLIGHTS {'✈️ '*3}")
            for i, flight in enumerate(results["other_flights"], 1):
                output.append(self._format_single_flight(flight, i + len(results.get("best_flights", []))))
        
        # Summary
        total_options = len(results.get("best_flights", [])) + len(results.get("other_flights", []))
        output.append(f"\n{'='*80}")
        output.append(f"📊 Total Flight Options Found: {total_options}")
        
        # Add helpful note for round-trip flights
        if results.get('search_parameters', {}).get('return_date'):
            output.append(f"\n💡 Note: For round-trip flights, this tool automatically fetches")
            output.append(f"   both outbound (🛫) and return (🛬) flight segments.")
        
        output.append("=" * 80)
        
        return "\n".join(output)
    
    def _format_single_flight(self, flight: Dict, index: int) -> str:
        """Format a single flight option with proper separation of outbound and return flights."""
        output = []
        output.append(f"\n--- Flight Option {index} ---")
        output.append(f"Price: {flight.get('price', 'N/A')} {flight.get('currency', 'USD')}")
        output.append(f"Total Duration: {self._format_duration(flight.get('total_duration', 0))}")
        output.append(f"Type: {flight.get('type', 'N/A')}")
        
        # Carbon emissions
        if flight.get('carbon_emissions'):
            emissions = flight['carbon_emissions']
            output.append(f"Carbon Emissions: {emissions.get('this_flight', 'N/A')} kg")
            if emissions.get('difference_percent'):
                output.append(f"  ({emissions['difference_percent']:+d}% vs typical)")
        
        # Flight segments - now properly separated for round-trip flights
        if flight.get('flights'):
            if flight.get('type') == 'Round trip':
                outbound_segments, return_segments = self._separate_round_trip_segments(flight['flights'])
                
                # Display outbound flights
                if outbound_segments:
                    output.append("\n🛫 OUTBOUND FLIGHTS:")
                    for j, segment in enumerate(outbound_segments, 1):
                        output.append(self._format_flight_segment(segment, j, is_outbound=True))
                
                # Display return flights  
                if return_segments:
                    output.append("\n🛬 RETURN FLIGHTS:")
                    for j, segment in enumerate(return_segments, 1):
                        output.append(self._format_flight_segment(segment, j, is_outbound=False))
                else:
                    output.append("\n🛬 RETURN FLIGHTS:")
                    output.append("  ⚠️  Return flight details not available or not fetched")
                    if flight.get("departure_token"):
                        output.append("  💡 Try enabling auto_fetch_return_flights=True")
            else:
                # For one-way or multi-city flights, display all segments chronologically
                output.append("\n✈️  FLIGHT DETAILS:")
                for j, segment in enumerate(flight['flights'], 1):
                    output.append(self._format_flight_segment(segment, j))
        
        # Layovers
        if flight.get('layovers'):
            output.append("\n🔄 LAYOVERS:")
            for layover in flight['layovers']:
                duration_str = self._format_duration(layover.get('duration', 0))
                overnight_str = " (Overnight)" if layover.get('overnight') else ""
                output.append(f"  {layover.get('name', 'N/A')} ({layover.get('id', 'N/A')}): {duration_str}{overnight_str}")
        
        # Debug info for return flights
        if flight.get('_return_flight_info'):
            info = flight['_return_flight_info']
            output.append(f"\n🔍 Return Flight Debug Info:")
            output.append(f"  Return segments: {info.get('return_segments_count', 'N/A')}")
            output.append(f"  Return duration: {self._format_duration(info.get('return_duration', 0))}")
        
        return "\n".join(output)
    
    def _separate_round_trip_segments(self, segments: List[Dict]) -> tuple:
        """
        Separate round-trip flight segments into outbound and return flights.
        
        This method now handles the properly combined round-trip data where
        outbound and return segments are in the same flights array.
        
        Args:
            segments (List[Dict]): All flight segments (outbound + return)
            
        Returns:
            tuple: (outbound_segments, return_segments)
        """
        if not segments:
            return [], []
        
        # For properly combined round-trip flights, we need to find the turnaround point
        # This is where the journey switches from going away from origin to returning
        
        if len(segments) <= 2:
            # Simple case: likely one segment each way
            outbound_segments = [segments[0]] if segments else []
            return_segments = [segments[1]] if len(segments) > 1 else []
        else:
            # More complex case: multiple segments, need to find the break point
            
            # Strategy 1: Look for time gaps (turnaround time at destination)
            # Strategy 2: Look for airport patterns (when we start heading back)
            
            original_departure = segments[0]['departure_airport']['id']
            final_arrival = segments[-1]['arrival_airport']['id']
            
            # Find the logical split
            best_split = len(segments) // 2  # Default to middle
            
            # Look for the point where we start heading back toward origin
            for i in range(1, len(segments)):
                current_departure = segments[i]['departure_airport']['id']
                current_arrival = segments[i]['arrival_airport']['id']
                
                # If this segment heads back to the original departure airport
                # or from the final destination, this is likely the return journey start
                if (current_arrival == original_departure or 
                    current_departure == final_arrival):
                    best_split = i
                    break
                
                # Alternative: look for a time gap that indicates turnaround
                if i < len(segments):
                    prev_arrival_time = segments[i-1]['arrival_airport'].get('time', '')
                    curr_departure_time = segments[i]['departure_airport'].get('time', '')
                    
                    # If there's a significant gap (like overnight), this might be the split
                    # This is a simplified check - in practice, you'd parse the times
                    
            outbound_segments = segments[:best_split]
            return_segments = segments[best_split:]
        
        return outbound_segments, return_segments
    
    def _format_flight_segment(self, segment: Dict, segment_num: int, is_outbound: bool = None) -> str:
        """Format a single flight segment with enhanced details."""
        dep_airport = segment.get('departure_airport', {})
        arr_airport = segment.get('arrival_airport', {})
        
        output = []
        direction_emoji = "→" if is_outbound is None else ("🛫" if is_outbound else "🛬")
        
        output.append(f"  {direction_emoji} Segment {segment_num}: {segment.get('airline', 'N/A')} {segment.get('flight_number', 'N/A')}")
        output.append(f"    Route: {dep_airport.get('id', 'N/A')} ({dep_airport.get('time', 'N/A')}) → "
                     f"{arr_airport.get('id', 'N/A')} ({arr_airport.get('time', 'N/A')})")
        output.append(f"    Duration: {self._format_duration(segment.get('duration', 0))}")
        output.append(f"    Aircraft: {segment.get('airplane', 'N/A')}")
        output.append(f"    Class: {segment.get('travel_class', 'N/A')}")
        
        # Additional details
        if segment.get('legroom'):
            output.append(f"    Legroom: {segment.get('legroom')}")
        
        if segment.get('overnight'):
            output.append(f"    ⚠️  Overnight flight")
        
        if segment.get('often_delayed_by_over_30_min'):
            output.append(f"    ⚠️  Often delayed by 30+ minutes")
        
        # Extensions (amenities)
        if segment.get('extensions'):
            amenities = segment['extensions']
            if amenities:
                output.append(f"    Amenities: {', '.join(amenities[:3])}{'...' if len(amenities) > 3 else ''}")
        
        return "\n".join(output)
    
    def _format_duration(self, minutes: int) -> str:
        """Convert minutes to readable duration format."""
        if not minutes:
            return "N/A"
        hours = minutes // 60
        mins = minutes % 60
        return f"{hours}h {mins}m"

print("✅ FlightSearcher class updated with enhanced debugging and return flight fetching!")
print("💡 Key improvements:")
print("   - Added detailed debug logging to track return flight fetching")
print("   - Enhanced error handling for departure token issues")
print("   - Improved combination logic for outbound and return flights")
print("🔧 Run a new search to see the debug output and verify functionality!")
# Out:
# ✅ FlightSearcher class updated with enhanced debugging and return flight fetching!
# 💡 Key improvements:
#    - Added detailed debug logging to track return flight fetching
#    - Enhanced error handling for departure token issues
#    - Improved combination logic for outbound and return flights
# 🔧 Run a new search to see the debug output and verify functionality!

# %% [markdown]
# ## 4. Initialize the Flight Searcher
#
# Now let's create an instance of our FlightSearcher class using the API key we loaded from the environment.

# %%
# Re-create FlightSearcher instance with the updated class
flight_searcher = FlightSearcher()

print("✅ Updated FlightSearcher instance created successfully!")
print("🎯 New features:")
print("   - Automatic return flight fetching for round-trip searches")
print("   - Combined outbound + return flight display")
print("   - Proper segment separation with visual indicators")
print("Ready to search for complete round-trip flights! 🛫🛬")
# Out:
# ✅ Updated FlightSearcher instance created successfully!
# 🎯 New features:
#    - Automatic return flight fetching for round-trip searches
#    - Combined outbound + return flight display
#    - Proper segment separation with visual indicators
# Ready to search for complete round-trip flights! 🛫🛬

# %% [markdown]
# ## 5. Example 1: Basic Round-Trip Flight Search
#
# Let's start with a simple example: searching for round-trip flights from Los Angeles (LAX) to New York JFK for a future date.

# %%
# Example 1: Basic round-trip flight search
print("🔍 Searching for flights from LAX to JFK...")

try:
    # Search for round-trip flights
    results = flight_searcher.search_flights(
        departure_id="AUS",
        arrival_id="JFK", 
        outbound_date="2025-07-15",  # Future date
        return_date="2025-07-22",    # One week later
        trip_type="round_trip",
        adults=1,
        travel_class="economy"
    )
    
    # Format and display results
    formatted_results = flight_searcher.format_flight_results(results)
    print(formatted_results)
    
    print("\n✅ Basic flight search completed successfully!")
    
except Exception as e:
    print(f"❌ Error during flight search: {e}")
    print("This might be due to API limits or network issues.")
# Out:
# 🔍 Searching for flights from LAX to JFK...
# 🔧 DEBUG: Fetching return flights for round-trip search...
# 🔧 DEBUG: _fetch_complete_round_trip called (all return options)
# 🔧 DEBUG: Found 5 best flights
# 🔧 DEBUG: Found 6 other flights
# 🔧 DEBUG: Processing flight 1/11
# 🔧 DEBUG: Found departure token for flight 1
# 🔧 DEBUG: Return flight response keys: ['search_metadata', 'search_parameters', 'other_flights', 'airports']
# 🔧 DEBUG: Return flight API call successful
# 🔧 DEBUG: _combine_outbound_all_return_flights called (with price fix)
# 🔧 DEBUG: Flight 1 combined with 4 return options
# 🔧 DEBUG: Processing flight 2/11
# 🔧 DEBUG: Found departure token for flight 2
# 🔧 DEBUG: Return flight response keys: ['search_metadata', 'search_parameters', 'other_flights', 'airports']
# 🔧 DEBUG: Return flight API call successful
# 🔧 DEBUG: _combine_outbound_all_return_flights called (with price fix)
# 🔧 DEBUG: Flight 2 combined with 4 return options
# 🔧 DEBUG: Processing flight 3/11
# 🔧 DEBUG: Found departure token for flight 3
# 🔧 DEBUG: Return flight response keys: ['search_metadata', 'search_parameters', 'other_flights', 'airports']
# 🔧 DEBUG: Return flight API call successful
# 🔧 DEBUG: _combine_outbound_all_return_flights called (with price fix)
# 🔧 DEBUG: Flight 3 combined with 4 return options
# 🔧 DEBUG: Processing flight 4/11
# 🔧 DEBUG: Found departure token for flight 4
# 🔧 DEBUG: Return flight response keys: ['search_metadata', 'search_parameters', 'other_flights', 'airports']
# 🔧 DEBUG: Return flight API call successful
# 🔧 DEBUG: _combine_outbound_all_return_flights called (with price fix)
# 🔧 DEBUG: Flight 4 combined with 4 return options
# 🔧 DEBUG: Processing flight 5/11
# 🔧 DEBUG: Found departure token for flight 5
# 🔧 DEBUG: Return flight response keys: ['search_metadata', 'search_parameters', 'best_flights', 'other_flights', 'airports']
# 🔧 DEBUG: Return flight API call successful
# 🔧 DEBUG: _combine_outbound_all_return_flights called (with price fix)
# 🔧 DEBUG: Flight 5 combined with 5 return options
# 🔧 DEBUG: Processing flight 6/11
# 🔧 DEBUG: Found departure token for flight 6
# 🔧 DEBUG: Return flight response keys: ['search_metadata', 'search_parameters', 'other_flights', 'airports']
# 🔧 DEBUG: Return flight API call successful
# 🔧 DEBUG: _combine_outbound_all_return_flights called (with price fix)
# 🔧 DEBUG: Flight 6 combined with 4 return options
# 🔧 DEBUG: Processing flight 7/11
# 🔧 DEBUG: Found departure token for flight 7
# 🔧 DEBUG: Return flight response keys: ['search_metadata', 'search_parameters', 'other_flights', 'airports']
# 🔧 DEBUG: Return flight API call successful
# 🔧 DEBUG: _combine_outbound_all_return_flights called (with price fix)
# 🔧 DEBUG: Flight 3 combined with 4 return options
# 🔧 DEBUG: Processing flight 4/11
# 🔧 DEBUG: Found departure token for flight 4
# 🔧 DEBUG: Return flight response keys: ['search_metadata', 'search_parameters', 'other_flights', 'airports']
# 🔧 DEBUG: Return flight API call successful
# 🔧 DEBUG: _combine_outbound_all_return_flights called (with price fix)
# 🔧 DEBUG: Flight 4 combined with 4 return options
# 🔧 DEBUG: Processing flight 5/11
# 🔧 DEBUG: Found departure token for flight 5
# 🔧 DEBUG: Return flight response keys: ['search_metadata', 'search_parameters', 'best_flights', 'other_flights', 'airports']
# 🔧 DEBUG: Return flight API call successful
# 🔧 DEBUG: _combine_outbound_all_return_flights called (with price fix)
# 🔧 DEBUG: Flight 5 combined with 5 return options
# 🔧 DEBUG: Processing flight 6/11
# 🔧 DEBUG: Found departure token for flight 6
# 🔧 DEBUG: Return flight response keys: ['search_metadata', 'search_parameters', 'other_flights', 'airports']
# 🔧 DEBUG: Return flight API call successful
# 🔧 DEBUG: _combine_outbound_all_return_flights called (with price fix)
# 🔧 DEBUG: Flight 6 combined with 4 return options
# 🔧 DEBUG: Processing flight 7/11
# 🔧 DEBUG: Found departure token for flight 7
# 🔧 DEBUG: Return flight response keys: ['search_metadata', 'search_parameters', 'best_flights', 'other_flights', 'airports']
# 🔧 DEBUG: Return flight API call successful
# 🔧 DEBUG: _combine_outbound_all_return_flights called (with price fix)
# 🔧 DEBUG: Flight 7 combined with 5 return options
# 🔧 DEBUG: Processing flight 8/11
# 🔧 DEBUG: Found departure token for flight 8
# 🔧 DEBUG: Return flight response keys: ['search_metadata', 'search_parameters', 'other_flights', 'airports']
# 🔧 DEBUG: Return flight API call successful
# 🔧 DEBUG: _combine_outbound_all_return_flights called (with price fix)
# 🔧 DEBUG: Flight 8 combined with 4 return options
# 🔧 DEBUG: Processing flight 9/11
# 🔧 DEBUG: Found departure token for flight 9
# 🔧 DEBUG: Return flight response keys: ['search_metadata', 'search_parameters', 'other_flights', 'airports']
# 🔧 DEBUG: Return flight API call successful
# 🔧 DEBUG: _combine_outbound_all_return_flights called (with price fix)
# 🔧 DEBUG: Flight 9 combined with 4 return options
# 🔧 DEBUG: Processing flight 10/11
# 🔧 DEBUG: Found departure token for flight 10
# 🔧 DEBUG: Return flight response keys: ['search_metadata', 'search_parameters', 'other_flights', 'airports']
# 🔧 DEBUG: Return flight API call successful
# 🔧 DEBUG: _combine_outbound_all_return_flights called (with price fix)
# 🔧 DEBUG: Flight 10 combined with 2 return options
# 🔧 DEBUG: Processing flight 11/11
# 🔧 DEBUG: Found departure token for flight 11
# 🔧 DEBUG: Return flight response keys: ['search_metadata', 'search_parameters', 'other_flights', 'airports']
# 🔧 DEBUG: Return flight API call successful
# 🔧 DEBUG: _combine_outbound_all_return_flights called (with price fix)
# 🔧 DEBUG: Flight 11 combined with 3 return options
# 🔧 DEBUG: Enhanced 43 total flights (all return options)
# 🔧 DEBUG: Return flight fetching completed
# ================================================================================
# ✈️  FLIGHT SEARCH RESULTS
# ================================================================================
#
# 📋 Search Parameters:
#   Route: AUS → JFK
#   Outbound: 2025-07-15
#   Return: 2025-07-22
#   Trip Type: Round Trip
#   Currency: USD
#
# 💰 Price Insights:
#   Lowest Price: 239 USD
#   Price Level: typical
#   Typical Range: 215 - 350 USD
#
# 🌟🌟🌟 BEST FLIGHTS 🌟🌟🌟
#
# --- Flight Option 1 ---
# Price: 239 USD
# Total Duration: 7h 54m
# Type: Round trip
# Carbon Emissions: 214000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 1411
#     Route: AUS (2025-07-15 07:38) → JFK (2025-07-15 12:30)
#     Duration: 3h 52m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1230
#     Route: JFK (2025-07-22 07:00) → AUS (2025-07-22 10:02)
#     Duration: 4h 2m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 2m
#
# --- Flight Option 2 ---
# Price: 239 USD
# Total Duration: 8h 0m
# Type: Round trip
# Carbon Emissions: 214000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 1411
#     Route: AUS (2025-07-15 07:38) → JFK (2025-07-15 12:30)
#     Duration: 3h 52m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 2323
#     Route: JFK (2025-07-22 11:35) → AUS (2025-07-22 14:43)
#     Duration: 4h 8m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 8m
#
# --- Flight Option 3 ---
# Price: 319 USD
# Total Duration: 8h 7m
# Type: Round trip
# Carbon Emissions: 214000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 1411
#     Route: AUS (2025-07-15 07:38) → JFK (2025-07-15 12:30)
#     Duration: 3h 52m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1643
#     Route: JFK (2025-07-22 14:29) → AUS (2025-07-22 17:44)
#     Duration: 4h 15m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 15m
#
# --- Flight Option 4 ---
# Price: 319 USD
# Total Duration: 8h 12m
# Type: Round trip
# Carbon Emissions: 214000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 1411
#     Route: AUS (2025-07-15 07:38) → JFK (2025-07-15 12:30)
#     Duration: 3h 52m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1233
#     Route: JFK (2025-07-22 18:20) → AUS (2025-07-22 21:40)
#     Duration: 4h 20m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 20m
#
# --- Flight Option 5 ---
# Price: 239 USD
# Total Duration: 8h 7m
# Type: Round trip
# Carbon Emissions: 214000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 1230
#     Route: AUS (2025-07-15 11:15) → JFK (2025-07-15 16:20)
#     Duration: 4h 5m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1230
#     Route: JFK (2025-07-22 07:00) → AUS (2025-07-22 10:02)
#     Duration: 4h 2m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 2m
#
# ✈️ ✈️ ✈️  OTHER FLIGHTS ✈️ ✈️ ✈️
#
# --- Flight Option 6 ---
# Price: 239 USD
# Total Duration: 8h 13m
# Type: Round trip
# Carbon Emissions: 214000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 1230
#     Route: AUS (2025-07-15 11:15) → JFK (2025-07-15 16:20)
#     Duration: 4h 5m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 2323
#     Route: JFK (2025-07-22 11:35) → AUS (2025-07-22 14:43)
#     Duration: 4h 8m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 8m
#
# --- Flight Option 7 ---
# Price: 319 USD
# Total Duration: 8h 20m
# Type: Round trip
# Carbon Emissions: 214000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 1230
#     Route: AUS (2025-07-15 11:15) → JFK (2025-07-15 16:20)
#     Duration: 4h 5m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1643
#     Route: JFK (2025-07-22 14:29) → AUS (2025-07-22 17:44)
#     Duration: 4h 15m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 15m
#
# --- Flight Option 8 ---
# Price: 319 USD
# Total Duration: 8h 25m
# Type: Round trip
# Carbon Emissions: 214000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 1230
#     Route: AUS (2025-07-15 11:15) → JFK (2025-07-15 16:20)
#     Duration: 4h 5m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1233
#     Route: JFK (2025-07-22 18:20) → AUS (2025-07-22 21:40)
#     Duration: 4h 20m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 20m
#
# --- Flight Option 9 ---
# Price: 239 USD
# Total Duration: 8h 22m
# Type: Round trip
# Carbon Emissions: 214000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2323
#     Route: AUS (2025-07-15 15:55) → JFK (2025-07-15 21:15)
#     Duration: 4h 20m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1230
#     Route: JFK (2025-07-22 07:00) → AUS (2025-07-22 10:02)
#     Duration: 4h 2m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 2m
#
# --- Flight Option 10 ---
# Price: 239 USD
# Total Duration: 8h 28m
# Type: Round trip
# Carbon Emissions: 214000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2323
#     Route: AUS (2025-07-15 15:55) → JFK (2025-07-15 21:15)
#     Duration: 4h 20m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 2323
#     Route: JFK (2025-07-22 11:35) → AUS (2025-07-22 14:43)
#     Duration: 4h 8m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 8m
#
# --- Flight Option 11 ---
# Price: 319 USD
# Total Duration: 8h 35m
# Type: Round trip
# Carbon Emissions: 214000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2323
#     Route: AUS (2025-07-15 15:55) → JFK (2025-07-15 21:15)
#     Duration: 4h 20m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1643
#     Route: JFK (2025-07-22 14:29) → AUS (2025-07-22 17:44)
#     Duration: 4h 15m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 15m
#
# --- Flight Option 12 ---
# Price: 319 USD
# Total Duration: 8h 40m
# Type: Round trip
# Carbon Emissions: 214000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2323
#     Route: AUS (2025-07-15 15:55) → JFK (2025-07-15 21:15)
#     Duration: 4h 20m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1233
#     Route: JFK (2025-07-22 18:20) → AUS (2025-07-22 21:40)
#     Duration: 4h 20m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 20m
#
# --- Flight Option 13 ---
# Price: 239 USD
# Total Duration: 7h 56m
# Type: Round trip
# Carbon Emissions: 214000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 1643
#     Route: AUS (2025-07-15 19:05) → JFK (2025-07-15 23:59)
#     Duration: 3h 54m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1230
#     Route: JFK (2025-07-22 07:00) → AUS (2025-07-22 10:02)
#     Duration: 4h 2m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 2m
#
# --- Flight Option 14 ---
# Price: 239 USD
# Total Duration: 8h 2m
# Type: Round trip
# Carbon Emissions: 214000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 1643
#     Route: AUS (2025-07-15 19:05) → JFK (2025-07-15 23:59)
#     Duration: 3h 54m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 2323
#     Route: JFK (2025-07-22 11:35) → AUS (2025-07-22 14:43)
#     Duration: 4h 8m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 8m
#
# --- Flight Option 15 ---
# Price: 319 USD
# Total Duration: 8h 9m
# Type: Round trip
# Carbon Emissions: 214000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 1643
#     Route: AUS (2025-07-15 19:05) → JFK (2025-07-15 23:59)
#     Duration: 3h 54m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1643
#     Route: JFK (2025-07-22 14:29) → AUS (2025-07-22 17:44)
#     Duration: 4h 15m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 15m
#
# --- Flight Option 16 ---
# Price: 319 USD
# Total Duration: 8h 14m
# Type: Round trip
# Carbon Emissions: 214000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 1643
#     Route: AUS (2025-07-15 19:05) → JFK (2025-07-15 23:59)
#     Duration: 3h 54m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1233
#     Route: JFK (2025-07-22 18:20) → AUS (2025-07-22 21:40)
#     Duration: 4h 20m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 20m
#
# --- Flight Option 17 ---
# Price: 308 USD
# Total Duration: 9h 50m
# Type: Round trip
# Carbon Emissions: 178000 kg
#   (-21% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 2292
#     Route: AUS (2025-07-15 06:06) → JFK (2025-07-15 11:00)
#     Duration: 3h 54m
#     Aircraft: Boeing 737MAX 8 Passenger
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 2: American AA 495
#     Route: JFK (2025-07-22 12:00) → CLT (2025-07-22 14:08)
#     Duration: 2h 8m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: American AA 1161
#     Route: CLT (2025-07-22 15:08) → AUS (2025-07-22 16:56)
#     Duration: 2h 48m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Charlotte Douglas International Airport (CLT): 1h 0m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 2
#   Return duration: 5h 56m
#
# --- Flight Option 18 ---
# Price: 317 USD
# Total Duration: 7h 56m
# Type: Round trip
# Carbon Emissions: 178000 kg
#   (-21% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 2292
#     Route: AUS (2025-07-15 06:06) → JFK (2025-07-15 11:00)
#     Duration: 3h 54m
#     Aircraft: Boeing 737MAX 8 Passenger
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: American AA 842
#     Route: JFK (2025-07-22 11:10) → AUS (2025-07-22 14:12)
#     Duration: 4h 2m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 2m
#
# --- Flight Option 19 ---
# Price: 317 USD
# Total Duration: 8h 7m
# Type: Round trip
# Carbon Emissions: 178000 kg
#   (-21% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 2292
#     Route: AUS (2025-07-15 06:06) → JFK (2025-07-15 11:00)
#     Duration: 3h 54m
#     Aircraft: Boeing 737MAX 8 Passenger
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: American AA 2772
#     Route: JFK (2025-07-22 20:46) → AUS (2025-07-22 23:59)
#     Duration: 4h 13m
#     Aircraft: Boeing 737MAX 8 Passenger
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 13m
#
# --- Flight Option 20 ---
# Price: 272 USD
# Total Duration: 15h 7m
# Type: Round trip
# Carbon Emissions: 178000 kg
#   (-21% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 2292
#     Route: AUS (2025-07-15 06:06) → JFK (2025-07-15 11:00)
#     Duration: 3h 54m
#     Aircraft: Boeing 737MAX 8 Passenger
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 2: American AA 4693
#     Route: JFK (2025-07-22 13:30) → BNA (2025-07-22 14:13)
#     Duration: 1h 43m
#     Aircraft: Embraer 175
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 3: American AA 2238
#     Route: BNA (2025-07-22 19:46) → DFW (2025-07-22 21:49)
#     Duration: 2h 3m
#     Aircraft: Airbus A320
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: American AA 1588
#     Route: DFW (2025-07-22 22:39) → AUS (2025-07-22 23:43)
#     Duration: 1h 4m
#     Aircraft: Airbus A321neo
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Nashville International Airport (BNA): 5h 33m
#   Dallas Fort Worth International Airport (DFW): 0h 50m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 3
#   Return duration: 11h 13m
#
# --- Flight Option 21 ---
# Price: 308 USD
# Total Duration: 10h 22m
# Type: Round trip
# Carbon Emissions: 178000 kg
#   (-21% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 2292
#     Route: AUS (2025-07-15 06:06) → JFK (2025-07-15 11:00)
#     Duration: 3h 54m
#     Aircraft: Boeing 737MAX 8 Passenger
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 2: American AA 1766
#     Route: JFK (2025-07-22 14:52) → DFW (2025-07-22 17:50)
#     Duration: 3h 58m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: American AA 789
#     Route: DFW (2025-07-22 19:15) → AUS (2025-07-22 20:20)
#     Duration: 1h 5m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Dallas Fort Worth International Airport (DFW): 1h 25m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 2
#   Return duration: 6h 28m
#
# --- Flight Option 22 ---
# Price: 266 USD
# Total Duration: 23h 13m
# Type: Round trip
# Carbon Emissions: 337000 kg
#   (+49% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 2928
#     Route: AUS (2025-07-15 07:00) → DFW (2025-07-15 08:13)
#     Duration: 1h 13m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 2: American AA 1396
#     Route: DFW (2025-07-15 10:08) → BNA (2025-07-15 12:02)
#     Duration: 1h 54m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 3: American AA 4693
#     Route: BNA (2025-07-15 16:27) → JFK (2025-07-15 20:00)
#     Duration: 2h 33m
#     Aircraft: Embraer 175
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 4: American AA 4693
#     Route: JFK (2025-07-22 13:30) → BNA (2025-07-22 14:13)
#     Duration: 1h 43m
#     Aircraft: Embraer 175
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 5: American AA 2238
#     Route: BNA (2025-07-22 19:46) → DFW (2025-07-22 21:49)
#     Duration: 2h 3m
#     Aircraft: Airbus A320
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: American AA 1588
#     Route: DFW (2025-07-22 22:39) → AUS (2025-07-22 23:43)
#     Duration: 1h 4m
#     Aircraft: Airbus A321neo
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Dallas Fort Worth International Airport (DFW): 1h 55m
#   Nashville International Airport (BNA): 4h 25m
#   Nashville International Airport (BNA): 5h 33m
#   Dallas Fort Worth International Airport (DFW): 0h 50m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 3
#   Return duration: 11h 13m
#
# --- Flight Option 23 ---
# Price: 325 USD
# Total Duration: 16h 2m
# Type: Round trip
# Carbon Emissions: 337000 kg
#   (+49% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 2928
#     Route: AUS (2025-07-15 07:00) → DFW (2025-07-15 08:13)
#     Duration: 1h 13m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 2: American AA 1396
#     Route: DFW (2025-07-15 10:08) → BNA (2025-07-15 12:02)
#     Duration: 1h 54m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 3: American AA 4693
#     Route: BNA (2025-07-15 16:27) → JFK (2025-07-15 20:00)
#     Duration: 2h 33m
#     Aircraft: Embraer 175
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: American AA 842
#     Route: JFK (2025-07-22 11:10) → AUS (2025-07-22 14:12)
#     Duration: 4h 2m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Dallas Fort Worth International Airport (DFW): 1h 55m
#   Nashville International Airport (BNA): 4h 25m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 2m
#
# --- Flight Option 24 ---
# Price: 325 USD
# Total Duration: 16h 13m
# Type: Round trip
# Carbon Emissions: 337000 kg
#   (+49% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 2928
#     Route: AUS (2025-07-15 07:00) → DFW (2025-07-15 08:13)
#     Duration: 1h 13m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 2: American AA 1396
#     Route: DFW (2025-07-15 10:08) → BNA (2025-07-15 12:02)
#     Duration: 1h 54m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 3: American AA 4693
#     Route: BNA (2025-07-15 16:27) → JFK (2025-07-15 20:00)
#     Duration: 2h 33m
#     Aircraft: Embraer 175
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: American AA 2772
#     Route: JFK (2025-07-22 20:46) → AUS (2025-07-22 23:59)
#     Duration: 4h 13m
#     Aircraft: Boeing 737MAX 8 Passenger
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Dallas Fort Worth International Airport (DFW): 1h 55m
#   Nashville International Airport (BNA): 4h 25m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 13m
#
# --- Flight Option 25 ---
# Price: 330 USD
# Total Duration: 17h 56m
# Type: Round trip
# Carbon Emissions: 337000 kg
#   (+49% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 2928
#     Route: AUS (2025-07-15 07:00) → DFW (2025-07-15 08:13)
#     Duration: 1h 13m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 2: American AA 1396
#     Route: DFW (2025-07-15 10:08) → BNA (2025-07-15 12:02)
#     Duration: 1h 54m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 3: American AA 4693
#     Route: BNA (2025-07-15 16:27) → JFK (2025-07-15 20:00)
#     Duration: 2h 33m
#     Aircraft: Embraer 175
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 4: American AA 495
#     Route: JFK (2025-07-22 12:00) → CLT (2025-07-22 14:08)
#     Duration: 2h 8m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: American AA 1161
#     Route: CLT (2025-07-22 15:08) → AUS (2025-07-22 16:56)
#     Duration: 2h 48m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Dallas Fort Worth International Airport (DFW): 1h 55m
#   Nashville International Airport (BNA): 4h 25m
#   Charlotte Douglas International Airport (CLT): 1h 0m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 2
#   Return duration: 5h 56m
#
# --- Flight Option 26 ---
# Price: 308 USD
# Total Duration: 9h 52m
# Type: Round trip
# Carbon Emissions: 209000 kg
#   (-8% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 3026
#     Route: AUS (2025-07-15 14:58) → JFK (2025-07-15 19:54)
#     Duration: 3h 56m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 2: American AA 495
#     Route: JFK (2025-07-22 12:00) → CLT (2025-07-22 14:08)
#     Duration: 2h 8m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: American AA 1161
#     Route: CLT (2025-07-22 15:08) → AUS (2025-07-22 16:56)
#     Duration: 2h 48m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Charlotte Douglas International Airport (CLT): 1h 0m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 2
#   Return duration: 5h 56m
#
# --- Flight Option 27 ---
# Price: 317 USD
# Total Duration: 7h 58m
# Type: Round trip
# Carbon Emissions: 209000 kg
#   (-8% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 3026
#     Route: AUS (2025-07-15 14:58) → JFK (2025-07-15 19:54)
#     Duration: 3h 56m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: American AA 842
#     Route: JFK (2025-07-22 11:10) → AUS (2025-07-22 14:12)
#     Duration: 4h 2m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 2m
#
# --- Flight Option 28 ---
# Price: 317 USD
# Total Duration: 8h 9m
# Type: Round trip
# Carbon Emissions: 209000 kg
#   (-8% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 3026
#     Route: AUS (2025-07-15 14:58) → JFK (2025-07-15 19:54)
#     Duration: 3h 56m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: American AA 2772
#     Route: JFK (2025-07-22 20:46) → AUS (2025-07-22 23:59)
#     Duration: 4h 13m
#     Aircraft: Boeing 737MAX 8 Passenger
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 13m
#
# --- Flight Option 29 ---
# Price: 272 USD
# Total Duration: 15h 9m
# Type: Round trip
# Carbon Emissions: 209000 kg
#   (-8% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 3026
#     Route: AUS (2025-07-15 14:58) → JFK (2025-07-15 19:54)
#     Duration: 3h 56m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 2: American AA 4693
#     Route: JFK (2025-07-22 13:30) → BNA (2025-07-22 14:13)
#     Duration: 1h 43m
#     Aircraft: Embraer 175
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 3: American AA 2238
#     Route: BNA (2025-07-22 19:46) → DFW (2025-07-22 21:49)
#     Duration: 2h 3m
#     Aircraft: Airbus A320
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: American AA 1588
#     Route: DFW (2025-07-22 22:39) → AUS (2025-07-22 23:43)
#     Duration: 1h 4m
#     Aircraft: Airbus A321neo
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Nashville International Airport (BNA): 5h 33m
#   Dallas Fort Worth International Airport (DFW): 0h 50m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 3
#   Return duration: 11h 13m
#
# --- Flight Option 30 ---
# Price: 308 USD
# Total Duration: 10h 24m
# Type: Round trip
# Carbon Emissions: 209000 kg
#   (-8% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 3026
#     Route: AUS (2025-07-15 14:58) → JFK (2025-07-15 19:54)
#     Duration: 3h 56m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 2: American AA 1766
#     Route: JFK (2025-07-22 14:52) → DFW (2025-07-22 17:50)
#     Duration: 3h 58m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: American AA 789
#     Route: DFW (2025-07-22 19:15) → AUS (2025-07-22 20:20)
#     Duration: 1h 5m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Dallas Fort Worth International Airport (DFW): 1h 25m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 2
#   Return duration: 6h 28m
#
# --- Flight Option 31 ---
# Price: 318 USD
# Total Duration: 10h 33m
# Type: Round trip
# Carbon Emissions: 231000 kg
#   (+2% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2886
#     Route: AUS (2025-07-15 12:04) → ATL (2025-07-15 15:28)
#     Duration: 2h 24m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#   🛫 Segment 2: Delta DL 2466
#     Route: ATL (2025-07-15 16:38) → JFK (2025-07-15 19:35)
#     Duration: 2h 57m
#     Aircraft: Boeing 767
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1230
#     Route: JFK (2025-07-22 07:00) → AUS (2025-07-22 10:02)
#     Duration: 4h 2m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Hartsfield-Jackson Atlanta International Airport (ATL): 1h 10m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 2m
#
# --- Flight Option 32 ---
# Price: 318 USD
# Total Duration: 10h 39m
# Type: Round trip
# Carbon Emissions: 231000 kg
#   (+2% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2886
#     Route: AUS (2025-07-15 12:04) → ATL (2025-07-15 15:28)
#     Duration: 2h 24m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#   🛫 Segment 2: Delta DL 2466
#     Route: ATL (2025-07-15 16:38) → JFK (2025-07-15 19:35)
#     Duration: 2h 57m
#     Aircraft: Boeing 767
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 2323
#     Route: JFK (2025-07-22 11:35) → AUS (2025-07-22 14:43)
#     Duration: 4h 8m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Hartsfield-Jackson Atlanta International Airport (ATL): 1h 10m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 8m
#
# --- Flight Option 33 ---
# Price: 398 USD
# Total Duration: 10h 46m
# Type: Round trip
# Carbon Emissions: 231000 kg
#   (+2% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2886
#     Route: AUS (2025-07-15 12:04) → ATL (2025-07-15 15:28)
#     Duration: 2h 24m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#   🛫 Segment 2: Delta DL 2466
#     Route: ATL (2025-07-15 16:38) → JFK (2025-07-15 19:35)
#     Duration: 2h 57m
#     Aircraft: Boeing 767
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1643
#     Route: JFK (2025-07-22 14:29) → AUS (2025-07-22 17:44)
#     Duration: 4h 15m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Hartsfield-Jackson Atlanta International Airport (ATL): 1h 10m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 15m
#
# --- Flight Option 34 ---
# Price: 398 USD
# Total Duration: 10h 51m
# Type: Round trip
# Carbon Emissions: 231000 kg
#   (+2% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2886
#     Route: AUS (2025-07-15 12:04) → ATL (2025-07-15 15:28)
#     Duration: 2h 24m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#   🛫 Segment 2: Delta DL 2466
#     Route: ATL (2025-07-15 16:38) → JFK (2025-07-15 19:35)
#     Duration: 2h 57m
#     Aircraft: Boeing 767
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1233
#     Route: JFK (2025-07-22 18:20) → AUS (2025-07-22 21:40)
#     Duration: 4h 20m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Hartsfield-Jackson Atlanta International Airport (ATL): 1h 10m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 20m
#
# --- Flight Option 35 ---
# Price: 318 USD
# Total Duration: 10h 0m
# Type: Round trip
# Carbon Emissions: 283000 kg
#   (+25% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2736
#     Route: AUS (2025-07-15 16:40) → DTW (2025-07-15 20:41)
#     Duration: 3h 1m
#     Aircraft: Airbus A320
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#   🛫 Segment 2: Delta DL 532
#     Route: DTW (2025-07-15 21:40) → JFK (2025-07-15 23:38)
#     Duration: 1h 58m
#     Aircraft: Airbus A319
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1230
#     Route: JFK (2025-07-22 07:00) → AUS (2025-07-22 10:02)
#     Duration: 4h 2m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Detroit Metropolitan Wayne County Airport (DTW): 0h 59m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 2m
#
# --- Flight Option 36 ---
# Price: 318 USD
# Total Duration: 10h 6m
# Type: Round trip
# Carbon Emissions: 283000 kg
#   (+25% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2736
#     Route: AUS (2025-07-15 16:40) → DTW (2025-07-15 20:41)
#     Duration: 3h 1m
#     Aircraft: Airbus A320
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#   🛫 Segment 2: Delta DL 532
#     Route: DTW (2025-07-15 21:40) → JFK (2025-07-15 23:38)
#     Duration: 1h 58m
#     Aircraft: Airbus A319
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 2323
#     Route: JFK (2025-07-22 11:35) → AUS (2025-07-22 14:43)
#     Duration: 4h 8m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Detroit Metropolitan Wayne County Airport (DTW): 0h 59m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 8m
#
# --- Flight Option 37 ---
# Price: 398 USD
# Total Duration: 10h 13m
# Type: Round trip
# Carbon Emissions: 283000 kg
#   (+25% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2736
#     Route: AUS (2025-07-15 16:40) → DTW (2025-07-15 20:41)
#     Duration: 3h 1m
#     Aircraft: Airbus A320
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#   🛫 Segment 2: Delta DL 532
#     Route: DTW (2025-07-15 21:40) → JFK (2025-07-15 23:38)
#     Duration: 1h 58m
#     Aircraft: Airbus A319
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1643
#     Route: JFK (2025-07-22 14:29) → AUS (2025-07-22 17:44)
#     Duration: 4h 15m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Detroit Metropolitan Wayne County Airport (DTW): 0h 59m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 15m
#
# --- Flight Option 38 ---
# Price: 398 USD
# Total Duration: 10h 18m
# Type: Round trip
# Carbon Emissions: 283000 kg
#   (+25% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2736
#     Route: AUS (2025-07-15 16:40) → DTW (2025-07-15 20:41)
#     Duration: 3h 1m
#     Aircraft: Airbus A320
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#   🛫 Segment 2: Delta DL 532
#     Route: DTW (2025-07-15 21:40) → JFK (2025-07-15 23:38)
#     Duration: 1h 58m
#     Aircraft: Airbus A319
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1233
#     Route: JFK (2025-07-22 18:20) → AUS (2025-07-22 21:40)
#     Duration: 4h 20m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Detroit Metropolitan Wayne County Airport (DTW): 0h 59m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 20m
#
# --- Flight Option 39 ---
# Price: 617 USD
# Total Duration: 27h 12m
# Type: Round trip
# Carbon Emissions: 497000 kg
#   (+120% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Alaska AS 3301
#     Route: AUS (2025-07-15 14:31) → SAN (2025-07-15 15:29)
#     Duration: 2h 58m
#     Aircraft: Embraer 175
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, Stream media to your device...
#   🛫 Segment 2: Alaska AS 36
#     Route: SAN (2025-07-15 21:56) → JFK (2025-07-16 06:29)
#     Duration: 5h 33m
#     Aircraft: Boeing 737MAX 9 Passenger
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Overnight flight
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 3: Alaska AS 17
#     Route: JFK (2025-07-22 18:53) → SEA (2025-07-22 22:22)
#     Duration: 6h 29m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Alaska AS 1227
#     Route: SEA (2025-07-22 23:59) → AUS (2025-07-23 06:07)
#     Duration: 4h 8m
#     Aircraft: Boeing 737MAX 9 Passenger
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Overnight flight
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   San Diego International Airport (SAN): 6h 27m
#   Seattle–Tacoma International Airport (SEA): 1h 37m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 2
#   Return duration: 12h 14m
#
# --- Flight Option 40 ---
# Price: 637 USD
# Total Duration: 28h 57m
# Type: Round trip
# Carbon Emissions: 497000 kg
#   (+120% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Alaska AS 3301
#     Route: AUS (2025-07-15 14:31) → SAN (2025-07-15 15:29)
#     Duration: 2h 58m
#     Aircraft: Embraer 175
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, Stream media to your device...
#   🛫 Segment 2: Alaska AS 36
#     Route: SAN (2025-07-15 21:56) → JFK (2025-07-16 06:29)
#     Duration: 5h 33m
#     Aircraft: Boeing 737MAX 9 Passenger
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Overnight flight
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 3: Alaska AS 35
#     Route: JFK (2025-07-22 10:00) → SAN (2025-07-22 12:52)
#     Duration: 5h 52m
#     Aircraft: Boeing 737MAX 9 Passenger
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# ...
#     Duration: 4h 2m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Hartsfield-Jackson Atlanta International Airport (ATL): 1h 10m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 2m
#
# --- Flight Option 32 ---
# Price: 318 USD
# Total Duration: 10h 39m
# Type: Round trip
# Carbon Emissions: 231000 kg
#   (+2% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2886
#     Route: AUS (2025-07-15 12:04) → ATL (2025-07-15 15:28)
#     Duration: 2h 24m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#   🛫 Segment 2: Delta DL 2466
#     Route: ATL (2025-07-15 16:38) → JFK (2025-07-15 19:35)
#     Duration: 2h 57m
#     Aircraft: Boeing 767
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 2323
#     Route: JFK (2025-07-22 11:35) → AUS (2025-07-22 14:43)
#     Duration: 4h 8m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Hartsfield-Jackson Atlanta International Airport (ATL): 1h 10m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 8m
#
# --- Flight Option 33 ---
# Price: 398 USD
# Total Duration: 10h 46m
# Type: Round trip
# Carbon Emissions: 231000 kg
#   (+2% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2886
#     Route: AUS (2025-07-15 12:04) → ATL (2025-07-15 15:28)
#     Duration: 2h 24m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#   🛫 Segment 2: Delta DL 2466
#     Route: ATL (2025-07-15 16:38) → JFK (2025-07-15 19:35)
#     Duration: 2h 57m
#     Aircraft: Boeing 767
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1643
#     Route: JFK (2025-07-22 14:29) → AUS (2025-07-22 17:44)
#     Duration: 4h 15m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Hartsfield-Jackson Atlanta International Airport (ATL): 1h 10m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 15m
#
# --- Flight Option 34 ---
# Price: 398 USD
# Total Duration: 10h 51m
# Type: Round trip
# Carbon Emissions: 231000 kg
#   (+2% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2886
#     Route: AUS (2025-07-15 12:04) → ATL (2025-07-15 15:28)
#     Duration: 2h 24m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#   🛫 Segment 2: Delta DL 2466
#     Route: ATL (2025-07-15 16:38) → JFK (2025-07-15 19:35)
#     Duration: 2h 57m
#     Aircraft: Boeing 767
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1233
#     Route: JFK (2025-07-22 18:20) → AUS (2025-07-22 21:40)
#     Duration: 4h 20m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Hartsfield-Jackson Atlanta International Airport (ATL): 1h 10m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 20m
#
# --- Flight Option 35 ---
# Price: 318 USD
# Total Duration: 10h 0m
# Type: Round trip
# Carbon Emissions: 283000 kg
#   (+25% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2736
#     Route: AUS (2025-07-15 16:40) → DTW (2025-07-15 20:41)
#     Duration: 3h 1m
#     Aircraft: Airbus A320
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#   🛫 Segment 2: Delta DL 532
#     Route: DTW (2025-07-15 21:40) → JFK (2025-07-15 23:38)
#     Duration: 1h 58m
#     Aircraft: Airbus A319
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1230
#     Route: JFK (2025-07-22 07:00) → AUS (2025-07-22 10:02)
#     Duration: 4h 2m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Detroit Metropolitan Wayne County Airport (DTW): 0h 59m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 2m
#
# --- Flight Option 36 ---
# Price: 318 USD
# Total Duration: 10h 6m
# Type: Round trip
# Carbon Emissions: 283000 kg
#   (+25% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2736
#     Route: AUS (2025-07-15 16:40) → DTW (2025-07-15 20:41)
#     Duration: 3h 1m
#     Aircraft: Airbus A320
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#   🛫 Segment 2: Delta DL 532
#     Route: DTW (2025-07-15 21:40) → JFK (2025-07-15 23:38)
#     Duration: 1h 58m
#     Aircraft: Airbus A319
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 2323
#     Route: JFK (2025-07-22 11:35) → AUS (2025-07-22 14:43)
#     Duration: 4h 8m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Detroit Metropolitan Wayne County Airport (DTW): 0h 59m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 8m
#
# --- Flight Option 37 ---
# Price: 398 USD
# Total Duration: 10h 13m
# Type: Round trip
# Carbon Emissions: 283000 kg
#   (+25% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2736
#     Route: AUS (2025-07-15 16:40) → DTW (2025-07-15 20:41)
#     Duration: 3h 1m
#     Aircraft: Airbus A320
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#   🛫 Segment 2: Delta DL 532
#     Route: DTW (2025-07-15 21:40) → JFK (2025-07-15 23:38)
#     Duration: 1h 58m
#     Aircraft: Airbus A319
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1643
#     Route: JFK (2025-07-22 14:29) → AUS (2025-07-22 17:44)
#     Duration: 4h 15m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Detroit Metropolitan Wayne County Airport (DTW): 0h 59m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 15m
#
# --- Flight Option 38 ---
# Price: 398 USD
# Total Duration: 10h 18m
# Type: Round trip
# Carbon Emissions: 283000 kg
#   (+25% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 2736
#     Route: AUS (2025-07-15 16:40) → DTW (2025-07-15 20:41)
#     Duration: 3h 1m
#     Aircraft: Airbus A320
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#   🛫 Segment 2: Delta DL 532
#     Route: DTW (2025-07-15 21:40) → JFK (2025-07-15 23:38)
#     Duration: 1h 58m
#     Aircraft: Airbus A319
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta DL 1233
#     Route: JFK (2025-07-22 18:20) → AUS (2025-07-22 21:40)
#     Duration: 4h 20m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Detroit Metropolitan Wayne County Airport (DTW): 0h 59m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 1
#   Return duration: 4h 20m
#
# --- Flight Option 39 ---
# Price: 617 USD
# Total Duration: 27h 12m
# Type: Round trip
# Carbon Emissions: 497000 kg
#   (+120% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Alaska AS 3301
#     Route: AUS (2025-07-15 14:31) → SAN (2025-07-15 15:29)
#     Duration: 2h 58m
#     Aircraft: Embraer 175
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, Stream media to your device...
#   🛫 Segment 2: Alaska AS 36
#     Route: SAN (2025-07-15 21:56) → JFK (2025-07-16 06:29)
#     Duration: 5h 33m
#     Aircraft: Boeing 737MAX 9 Passenger
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Overnight flight
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 3: Alaska AS 17
#     Route: JFK (2025-07-22 18:53) → SEA (2025-07-22 22:22)
#     Duration: 6h 29m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Alaska AS 1227
#     Route: SEA (2025-07-22 23:59) → AUS (2025-07-23 06:07)
#     Duration: 4h 8m
#     Aircraft: Boeing 737MAX 9 Passenger
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Overnight flight
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   San Diego International Airport (SAN): 6h 27m
#   Seattle–Tacoma International Airport (SEA): 1h 37m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 2
#   Return duration: 12h 14m
#
# --- Flight Option 40 ---
# Price: 637 USD
# Total Duration: 28h 57m
# Type: Round trip
# Carbon Emissions: 497000 kg
#   (+120% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Alaska AS 3301
#     Route: AUS (2025-07-15 14:31) → SAN (2025-07-15 15:29)
#     Duration: 2h 58m
#     Aircraft: Embraer 175
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, Stream media to your device...
#   🛫 Segment 2: Alaska AS 36
#     Route: SAN (2025-07-15 21:56) → JFK (2025-07-16 06:29)
#     Duration: 5h 33m
#     Aircraft: Boeing 737MAX 9 Passenger
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Overnight flight
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 3: Alaska AS 35
#     Route: JFK (2025-07-22 10:00) → SAN (2025-07-22 12:52)
#     Duration: 5h 52m
#     Aircraft: Boeing 737MAX 9 Passenger
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Alaska AS 3292
#     Route: SAN (2025-07-22 17:48) → AUS (2025-07-22 22:59)
#     Duration: 3h 11m
#     Aircraft: Embraer 175
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, Stream media to your device...
#
# 🔄 LAYOVERS:
#   San Diego International Airport (SAN): 6h 27m
#   San Diego International Airport (SAN): 4h 56m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 2
#   Return duration: 13h 59m
#
# --- Flight Option 41 ---
# Price: 641 USD
# Total Duration: 22h 46m
# Type: Round trip
# Carbon Emissions: 507000 kg
#   (+124% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Alaska AS 339
#     Route: AUS (2025-07-15 19:30) → SEA (2025-07-15 22:00)
#     Duration: 4h 30m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 2: Alaska AS 22
#     Route: SEA (2025-07-15 22:41) → JFK (2025-07-16 07:02)
#     Duration: 5h 21m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Overnight flight
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 3: Alaska AS 17
#     Route: JFK (2025-07-22 18:53) → SEA (2025-07-22 22:22)
#     Duration: 6h 29m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Alaska AS 1227
#     Route: SEA (2025-07-22 23:59) → AUS (2025-07-23 06:07)
#     Duration: 4h 8m
#     Aircraft: Boeing 737MAX 9 Passenger
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Overnight flight
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Seattle–Tacoma International Airport (SEA): 0h 41m
#   Seattle–Tacoma International Airport (SEA): 1h 37m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 2
#   Return duration: 12h 14m
#
# --- Flight Option 42 ---
# Price: 661 USD
# Total Duration: 24h 31m
# Type: Round trip
# Carbon Emissions: 507000 kg
#   (+124% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Alaska AS 339
#     Route: AUS (2025-07-15 19:30) → SEA (2025-07-15 22:00)
#     Duration: 4h 30m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 2: Alaska AS 22
#     Route: SEA (2025-07-15 22:41) → JFK (2025-07-16 07:02)
#     Duration: 5h 21m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Overnight flight
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 3: Alaska AS 35
#     Route: JFK (2025-07-22 10:00) → SAN (2025-07-22 12:52)
#     Duration: 5h 52m
#     Aircraft: Boeing 737MAX 9 Passenger
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Alaska AS 3292
#     Route: SAN (2025-07-22 17:48) → AUS (2025-07-22 22:59)
#     Duration: 3h 11m
#     Aircraft: Embraer 175
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, Stream media to your device...
#
# 🔄 LAYOVERS:
#   Seattle–Tacoma International Airport (SEA): 0h 41m
#   San Diego International Airport (SAN): 4h 56m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 2
#   Return duration: 13h 59m
#
# --- Flight Option 43 ---
# Price: 751 USD
# Total Duration: 22h 37m
# Type: Round trip
# Carbon Emissions: 507000 kg
#   (+124% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Alaska AS 339
#     Route: AUS (2025-07-15 19:30) → SEA (2025-07-15 22:00)
#     Duration: 4h 30m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 2: Alaska AS 22
#     Route: SEA (2025-07-15 22:41) → JFK (2025-07-16 07:02)
#     Duration: 5h 21m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Overnight flight
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#   🛫 Segment 3: Alaska AS 23
#     Route: JFK (2025-07-22 13:00) → SEA (2025-07-22 16:08)
#     Duration: 6h 8m
#     Aircraft: Boeing 737MAX 9 Passenger
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Alaska AS 372
#     Route: SEA (2025-07-22 17:56) → AUS (2025-07-23 00:05)
#     Duration: 4h 9m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🔄 LAYOVERS:
#   Seattle–Tacoma International Airport (SEA): 0h 41m
#   Seattle–Tacoma International Airport (SEA): 1h 48m
#
# 🔍 Return Flight Debug Info:
#   Return segments: 2
#   Return duration: 12h 5m
#
# ================================================================================
# 📊 Total Flight Options Found: 43
#
# 💡 Note: For round-trip flights, this tool automatically fetches
#    both outbound (🛫) and return (🛬) flight segments.
# ================================================================================
#
# ✅ Basic flight search completed successfully!

# %%
# Let's examine the structure of the results to understand the departure_token issue
print("🔍 Inspecting the flight data structure...")
print("=" * 60)

# Check if we have results and what the structure looks like
if 'results' in locals() and results:
    print("📊 Search Parameters:")
    if "search_parameters" in results:
        for key, value in results["search_parameters"].items():
            print(f"  {key}: {value}")
    
    print(f"\n📋 Available top-level keys in results:")
    for key in results.keys():
        print(f"  - {key}")
    
    # Check the first flight option structure
    if "best_flights" in results and results["best_flights"]:
        first_flight = results["best_flights"][0]
        print(f"\n✈️  First flight structure:")
        for key, value in first_flight.items():
            if key == "flights":
                print(f"  {key}: {len(value)} segments")
                for i, segment in enumerate(value):
                    dep_airport = segment.get('departure_airport', {})
                    arr_airport = segment.get('arrival_airport', {})
                    print(f"    Segment {i+1}: {dep_airport.get('id', 'N/A')} → {arr_airport.get('id', 'N/A')} ({dep_airport.get('time', 'N/A')} - {arr_airport.get('time', 'N/A')})")
            elif key == "departure_token":
                print(f"  🎟️  {key}: {value[:50]}..." if isinstance(value, str) and len(value) > 50 else f"  🎟️  {key}: {value}")
            else:
                print(f"  {key}: {value}")
    
    print(f"\n💡 Key Finding:")
    if "best_flights" in results and results["best_flights"] and "departure_token" in results["best_flights"][0]:
        print("✅ departure_token found! This means we need a second API call to get return flights.")
        print("❌ Current implementation only shows outbound flights - this explains the missing return flights!")
    else:
        print("❌ No departure_token found in the data structure.")
        
else:
    print("❌ No results available. Please run the search first.")
# Out:
# 🔍 Inspecting the flight data structure...
# ============================================================
# 📊 Search Parameters:
#   engine: google_flights
#   hl: en
#   gl: us
#   type: 1
#   departure_id: AUS
#   arrival_id: JFK
#   outbound_date: 2025-07-15
#   return_date: 2025-07-22
#   travel_class: 1
#   adults: 1
#   currency: USD
#
# 📋 Available top-level keys in results:
#   - search_metadata
#   - search_parameters
#   - best_flights
#   - other_flights
#   - price_insights
#   - airports
#
# ✈️  First flight structure:
#   flights: 1 segments
#     Segment 1: AUS → JFK (2025-07-15 07:38 - 2025-07-15 12:30)
#   total_duration: 232
#   carbon_emissions: {'this_flight': 214000, 'typical_for_this_route': 226000, 'difference_percent': -5}
#   price: 239
#   type: Round trip
#   airline_logo: https://www.gstatic.com/flights/airline_logos/70px/DL.png
#   extensions: ['Checked baggage for a fee', 'Bag and fare conditions depend on the return flight']
#   🎟️  departure_token: WyJDalJJTWtGblRUbHdiQzAyZDBGQlJtUjFNMEZDUnkwdExTMH...
#
# 💡 Key Finding:
# ✅ departure_token found! This means we need a second API call to get return flights.
# ❌ Current implementation only shows outbound flights - this explains the missing return flights!

# %%
# Test the updated round-trip functionality
print("🧪 Testing updated round-trip flight search with automatic return flight fetching...")
print("=" * 80)

try:
    # Search with the updated functionality
    updated_results = flight_searcher.search_flights(
        departure_id="DFW",          # Dallas
        arrival_id="LAX",            # Los Angeles
        outbound_date="2025-07-20",  # Future date
        return_date="2025-07-27",    # One week later
        trip_type="round_trip",
        adults=1,
        travel_class="economy",
        max_price=600,               # Reasonable price limit
        auto_fetch_return_flights=True  # Enable automatic return flight fetching
    )
    
    # Format and display the results
    formatted_updated = flight_searcher.format_flight_results(updated_results)
    print(formatted_updated)
    
    print("\n✅ Updated round-trip search completed!")
    print("🎯 This should now show BOTH outbound AND return flights!")
    
except Exception as e:
    print(f"❌ Error during updated flight search: {e}")
    print("This might be due to API limits or network issues.")
    import traceback
    traceback.print_exc()
# Out:
# 🧪 Testing updated round-trip flight search with automatic return flight fetching...
# ================================================================================
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1pPU3pFeU56SWFDZ2ppZlJBQ0dnTlZVMFE0SEhEaWZRPT0iLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIk5LIiwiMTI3MiJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1pPU3pFd01qQWFDZ2ppZlJBQ0dnTlZVMFE0SEhEaWZRPT0iLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIk5LIiwiMTAyMCJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1pCUVRJd01EVWFDd2pUeFFFUUFob0RWVk5FT0J4dzA4VUIiLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIkFBIiwiMjAwNSJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1ZFVERRek9Sb0xDUHpIQVJBQ0dnTlZVMFE0SEhEOHh3RT0iLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIkRMIiwiNDM5Il1dXQ%3D%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1pHT1RNeU1URWFDd2pueVFFUUFob0RWVk5FT0J4dzU4a0IiLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIkY5IiwiMzIxMSJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1pCUVRNek1UY2FDd2laMHdFUUFob0RWVk5FT0J4d21kTUIiLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIkFBIiwiMzMxNyJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1pCUVRFd09EUWFDd2pOMVFFUUFob0RWVk5FT0J4d3pkVUIiLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIkFBIiwiMTA4NCJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1pCUVRNeE16WWFDd2o3MkFFUUFob0RWVk5FT0J4dys5Z0IiLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIkFBIiwiMzEzNiJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1pCUVRFeE5UUWFDd2lsNkFFUUFob0RWVk5FT0J4d3BlZ0IiLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIkFBIiwiMTE1NCJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1pCUVRNd01EY2FDd2p3K0FFUUFob0RWVk5FT0J4dzhQZ0IiLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIkFBIiwiMzAwNyJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1pCUVRJM05qY2FDd2lKL0FFUUFob0RWVk5FT0J4d2lmd0IiLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIkFBIiwiMjc2NyJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1ZCUVRVd01Cb0xDTHlTQWhBQ0dnTlZVMFE0SEhDOGtnST0iLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIkFBIiwiNTAwIl1dXQ%3D%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1pCUVRJNE1qY2FDd2k4a2dJUUFob0RWVk5FT0J4d3ZKSUMiLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIkFBIiwiMjgyNyJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1pCUVRFME9EUWFDd2k4a2dJUUFob0RWVk5FT0J4d3ZKSUMiLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIkFBIiwiMTQ4NCJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1pCUVRFNU9Ua2FDd2k4a2dJUUFob0RWVk5FT0J4d3ZKSUMiLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIkFBIiwiMTk5OSJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1ZCUVRRME1ob0xDTHlhQWhBQ0dnTlZVMFE0SEhDOG1nST0iLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIkFBIiwiNDQyIl1dXQ%3D%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1pCUVRNek1qZ2FDd2lRb3dJUUFob0RWVk5FT0J4d2tLTUMiLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIkFBIiwiMzMyOCJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1ZFVERrME9Cb0xDSkMyQWhBQ0dnTlZVMFE0SEhDUXRnST0iLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIkRMIiwiOTQ4Il1dXQ%3D%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1pCUVRFMk5qa2FDd2lQOXdJUUFob0RWVk5FT0J4d2ovY0MiLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIkFBIiwiMTY2OSJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# ================================================================================
# ✈️  FLIGHT SEARCH RESULTS
# ================================================================================
#
# 📋 Search Parameters:
#   Route: DFW → LAX
#   Outbound: 2025-07-20
#   Return: 2025-07-27
#   Trip Type: Round Trip
#   Currency: USD
#
# 💰 Price Insights:
#   Lowest Price: 161 USD
#   Price Level: typical
#   Typical Range: 125 - 230 USD
#
# 🌟🌟🌟 BEST FLIGHTS 🌟🌟🌟
#
# --- Flight Option 1 ---
# Price: 161 USD
# Total Duration: 3h 20m
# Type: Round trip
# Carbon Emissions: 159000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Spirit NK 1272
#     Route: DFW (2025-07-20 05:45) → LAX (2025-07-20 07:05)
#     Duration: 3h 20m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 28 in
#     Amenities: Below average legroom (28 in), Carbon emissions estimate: 159 kg
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 2 ---
# Price: 161 USD
# Total Duration: 3h 27m
# Type: Round trip
# Carbon Emissions: 145000 kg
#   (-14% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Spirit NK 1020
#     Route: DFW (2025-07-20 21:03) → LAX (2025-07-20 22:30)
#     Duration: 3h 27m
#     Aircraft: Airbus A320neo
#     Class: Economy
#     Legroom: 28 in
#     Amenities: Below average legroom (28 in), Wi-Fi for a fee, Carbon emissions estimate: 144 kg
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 3 ---
# Price: 253 USD
# Total Duration: 3h 5m
# Type: Round trip
# Carbon Emissions: 138000 kg
#   (-18% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 2005
#     Route: DFW (2025-07-20 06:02) → LAX (2025-07-20 07:07)
#     Duration: 3h 5m
#     Aircraft: Airbus A321neo
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 4 ---
# Price: 256 USD
# Total Duration: 3h 10m
# Type: Round trip
# Carbon Emissions: 171000 kg
#   (+2% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 439
#     Route: DFW (2025-07-20 06:15) → LAX (2025-07-20 07:25)
#     Duration: 3h 10m
#     Aircraft: Airbus A320
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 5 ---
# Price: 259 USD
# Total Duration: 3h 18m
# Type: Round trip
# Carbon Emissions: 127000 kg
#   (-24% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Frontier F9 3211
#     Route: DFW (2025-07-20 16:39) → LAX (2025-07-20 17:57)
#     Duration: 3h 18m
#     Aircraft: Airbus A321neo
#     Class: Economy
#     Legroom: 28 in
#     Amenities: Below average legroom (28 in), Carbon emissions estimate: 127 kg
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# ✈️ ✈️ ✈️  OTHER FLIGHTS ✈️ ✈️ ✈️
#
# --- Flight Option 6 ---
# Price: 271 USD
# Total Duration: 3h 9m
# Type: Round trip
# Carbon Emissions: 175000 kg
#   (+4% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 3317
#     Route: DFW (2025-07-20 07:00) → LAX (2025-07-20 08:09)
#     Duration: 3h 9m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 7 ---
# Price: 274 USD
# Total Duration: 3h 10m
# Type: Round trip
# Carbon Emissions: 158000 kg
#   (-6% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 1084
#     Route: DFW (2025-07-20 20:45) → LAX (2025-07-20 21:55)
#     Duration: 3h 10m
#     Aircraft: Boeing 777
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 8 ---
# Price: 278 USD
# Total Duration: 3h 11m
# Type: Round trip
# Carbon Emissions: 160000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 3136
#     Route: DFW (2025-07-20 21:37) → LAX (2025-07-20 22:48)
#     Duration: 3h 11m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 9 ---
# Price: 298 USD
# Total Duration: 3h 13m
# Type: Round trip
# Carbon Emissions: 138000 kg
#   (-18% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 1154
#     Route: DFW (2025-07-20 08:25) → LAX (2025-07-20 09:38)
#     Duration: 3h 13m
#     Aircraft: Airbus A321neo
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 10 ---
# Price: 319 USD
# Total Duration: 3h 10m
# Type: Round trip
# Carbon Emissions: 158000 kg
#   (-6% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 3007
#     Route: DFW (2025-07-20 18:30) → LAX (2025-07-20 19:40)
#     Duration: 3h 10m
#     Aircraft: Boeing 777
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 11 ---
# Price: 323 USD
# Total Duration: 3h 5m
# Type: Round trip
# Carbon Emissions: 175000 kg
#   (+4% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 2767
#     Route: DFW (2025-07-20 17:14) → LAX (2025-07-20 18:19)
#     Duration: 3h 5m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 12 ---
# Price: 352 USD
# Total Duration: 3h 6m
# Type: Round trip
# Carbon Emissions: 175000 kg
#   (+4% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 500
#     Route: DFW (2025-07-20 09:12) → LAX (2025-07-20 10:18)
#     Duration: 3h 6m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 13 ---
# Price: 352 USD
# Total Duration: 3h 7m
# Type: Round trip
# Carbon Emissions: 138000 kg
#   (-18% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 2827
#     Route: DFW (2025-07-20 11:34) → LAX (2025-07-20 12:41)
#     Duration: 3h 7m
#     Aircraft: Airbus A321neo
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 14 ---
# Price: 352 USD
# Total Duration: 3h 5m
# Type: Round trip
# Carbon Emissions: 175000 kg
#   (+4% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 1484
#     Route: DFW (2025-07-20 13:17) → LAX (2025-07-20 14:22)
#     Duration: 3h 5m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 15 ---
# Price: 352 USD
# Total Duration: 3h 8m
# Type: Round trip
# Carbon Emissions: 175000 kg
#   (+4% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 1999
#     Route: DFW (2025-07-20 22:30) → LAX (2025-07-20 23:38)
#     Duration: 3h 8m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 16 ---
# Price: 362 USD
# Total Duration: 3h 12m
# Type: Round trip
# Carbon Emissions: 138000 kg
#   (-18% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 442
#     Route: DFW (2025-07-20 10:30) → LAX (2025-07-20 11:42)
#     Duration: 3h 12m
#     Aircraft: Airbus A321neo
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 17 ---
# Price: 373 USD
# Total Duration: 3h 5m
# Type: Round trip
# Carbon Emissions: 175000 kg
#   (+4% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 3328
#     Route: DFW (2025-07-20 19:40) → LAX (2025-07-20 20:45)
#     Duration: 3h 5m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 18 ---
# Price: 397 USD
# Total Duration: 3h 12m
# Type: Round trip
# Carbon Emissions: 171000 kg
#   (+2% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 948
#     Route: DFW (2025-07-20 16:20) → LAX (2025-07-20 17:32)
#     Duration: 3h 12m
#     Aircraft: Airbus A320
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 19 ---
# Price: 481 USD
# Total Duration: 3h 6m
# Type: Round trip
# Carbon Emissions: 160000 kg
#   (-5% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 1669
#     Route: DFW (2025-07-20 16:21) → LAX (2025-07-20 17:27)
#     Duration: 3h 6m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# ================================================================================
# 📊 Total Flight Options Found: 19
#
# 💡 Note: For round-trip flights, this tool automatically fetches
#    both outbound (🛫) and return (🛬) flight segments.
# ================================================================================
#
# ✅ Updated round-trip search completed!
# 🎯 This should now show BOTH outbound AND return flights!

# %%
# 🧪 VERIFICATION: Check if return flights are now properly fetched
print("🔍 VERIFICATION: Checking if return flights are properly fetched...")
print("=" * 70)

# Check the updated_results from the previous test
if 'updated_results' in locals() and updated_results:
    total_flights = len(updated_results.get("best_flights", [])) + len(updated_results.get("other_flights", []))
    print(f"✅ Total flight options found: {total_flights}")
    
    # Check the first flight to see if it has return segments
    if updated_results.get("best_flights"):
        first_flight = updated_results["best_flights"][0]
        flight_segments = first_flight.get("flights", [])
        
        print(f"\n🛫 Flight Analysis:")
        print(f"  Trip Type: {first_flight.get('type', 'N/A')}")
        print(f"  Total Segments: {len(flight_segments)}")
        print(f"  Price: {first_flight.get('price', 'N/A')} {first_flight.get('currency', 'USD')}")
        
        if len(flight_segments) >= 2:
            print(f"\n📍 Segment Details:")
            for i, segment in enumerate(flight_segments):
                dep = segment.get('departure_airport', {})
                arr = segment.get('arrival_airport', {})
                print(f"    Segment {i+1}: {dep.get('id', 'N/A')} → {arr.get('id', 'N/A')} at {dep.get('time', 'N/A')}")
            
            # Check if this looks like a proper round-trip
            origin = flight_segments[0]['departure_airport']['id']
            final_destination = flight_segments[-1]['arrival_airport']['id']
            
            if origin == final_destination:
                print(f"\n🎯 SUCCESS! This appears to be a complete round-trip:")
                print(f"   Origin: {origin}")
                print(f"   Final destination: {final_destination}")
                print(f"   ✅ Both outbound AND return flights are included!")
            else:
                print(f"\n⚠️  Potential issue:")
                print(f"   Origin: {origin}")
                print(f"   Final destination: {final_destination}")
                print(f"   These don't match - might need debugging")
        
        # Check for return flight debug info
        if first_flight.get('_return_flight_info'):
            info = first_flight['_return_flight_info']
            print(f"\n🔍 Return Flight Debug Info Found:")
            print(f"   Return segments: {info.get('return_segments_count', 'N/A')}")
            print(f"   Return duration: {info.get('return_duration', 'N/A')} minutes")
            print(f"   Return price: {info.get('return_price', 'N/A')} {info.get('return_currency', 'USD')}")
        
        print(f"\n🏆 CONCLUSION:")
        if len(flight_segments) >= 2 and origin == final_destination:
            print("✅ SUCCESS! The enhanced round-trip search is working correctly!")
            print("✅ Both outbound and return flights are being fetched and combined!")
        else:
            print("❌ The round-trip search may need additional debugging.")
    
else:
    print("❌ No test results available. Please run the previous test cell first.")

print("\n" + "=" * 70)
# Out:
# 🔍 VERIFICATION: Checking if return flights are properly fetched...
# ======================================================================
# ✅ Total flight options found: 19
#
# 🛫 Flight Analysis:
#   Trip Type: Round trip
#   Total Segments: 1
#   Price: 161 USD
#
# 🏆 CONCLUSION:
# ❌ The round-trip search may need additional debugging.
#
# ======================================================================

# %%
# 🔧 DIAGNOSTIC: Check what's happening with departure tokens
print("🔧 DIAGNOSTIC: Investigating departure token issue...")
print("=" * 60)

if 'updated_results' in locals() and updated_results:
    print("📋 Checking departure tokens in the results:")
    
    # Check best flights for departure tokens
    if updated_results.get("best_flights"):
        for i, flight in enumerate(updated_results["best_flights"][:3]):  # Check first 3
            print(f"\nFlight {i+1}:")
            print(f"  Type: {flight.get('type', 'N/A')}")
            print(f"  Segments: {len(flight.get('flights', []))}")
            
            # Check for departure token
            if 'departure_token' in flight:
                token = flight['departure_token']
                print(f"  🎟️  Departure Token: {token[:30]}...{token[-10:] if len(token) > 40 else token}")
                print("  ✅ Departure token found - should trigger return flight fetch")
            else:
                print("  ❌ No departure token found")
            
            # Check for return flight debug info
            if '_return_flight_info' in flight:
                info = flight['_return_flight_info']
                print(f"  🔍 Return flight info: {info}")
            else:
                print("  ❌ No return flight debug info")

# Let's test the departure token fetching manually for one flight
if (updated_results.get("best_flights") and 
    updated_results["best_flights"][0].get("departure_token")):
    
    print(f"\n🧪 MANUAL TEST: Trying to fetch return flight manually...")
    token = updated_results["best_flights"][0]["departure_token"]
    
    try:
        print(f"Using token: {token[:30]}...")
        return_results = flight_searcher._fetch_return_flights(token)
        
        print(f"✅ Return flight fetch successful!")
        print(f"Return results keys: {list(return_results.keys())}")
        
        if return_results.get("best_flights"):
            return_flight = return_results["best_flights"][0]
            print(f"Return flight segments: {len(return_flight.get('flights', []))}")
            print(f"Return flight price: {return_flight.get('price')} {return_flight.get('currency')}")
        
    except Exception as e:
        print(f"❌ Error fetching return flights: {e}")

print("\n" + "=" * 60)
# Out:
# 🔧 DIAGNOSTIC: Investigating departure token issue...
# ============================================================
# 📋 Checking departure tokens in the results:
#
# Flight 1:
#   Type: Round trip
#   Segments: 1
#   🎟️  Departure Token: WyJDalJJYWpoSFZsTnBjMXBMYVdOQl...I3MiJdXV0=
#   ✅ Departure token found - should trigger return flight fetch
#   ❌ No return flight debug info
#
# Flight 2:
#   Type: Round trip
#   Segments: 1
#   🎟️  Departure Token: WyJDalJJYWpoSFZsTnBjMXBMYVdOQl...AyMCJdXV0=
#   ✅ Departure token found - should trigger return flight fetch
#   ❌ No return flight debug info
#
# Flight 3:
#   Type: Round trip
#   Segments: 1
#   🎟️  Departure Token: WyJDalJJYWpoSFZsTnBjMXBMYVdOQl...AwNSJdXV0=
#   ✅ Departure token found - should trigger return flight fetch
#   ❌ No return flight debug info
#
# 🧪 MANUAL TEST: Trying to fetch return flight manually...
# Using token: WyJDalJJYWpoSFZsTnBjMXBMYVdOQl...
# ❌ Error fetching return flights: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJYWpoSFZsTnBjMXBMYVdOQlJXczFSa0ZDUnkwdExTMHRMUzB0ZG5kaVpua3lNRUZCUVVGQlIyaFpVWEJ6U25KUVEzVkJFZ1pPU3pFeU56SWFDZ2ppZlJBQ0dnTlZVMFE0SEhEaWZRPT0iLFtbIkRGVyIsIjIwMjUtMDctMjAiLCJMQVgiLG51bGwsIk5LIiwiMTI3MiJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
#
# ============================================================

# %%
# 🧪 FINAL TEST: Simple Round-Trip Search
print("🧪 Final test: Round-trip search DFW → LAX with automatic return flight fetching")
print("=" * 80)

try:
    # Simple round-trip search
    test_results = flight_searcher.search_flights(
        departure_id="DFW",          # Dallas
        arrival_id="LAX",            # Los Angeles  
        outbound_date="2025-08-01",  # Future date
        return_date="2025-08-08",    # One week later
        trip_type="round_trip",
        adults=1,
        travel_class="economy"
    )
    
    print("✅ Search completed! Analyzing results...")
    
    # Check if we have results
    if "error" in test_results:
        print(f"❌ Error in search: {test_results['error']}")
    elif "best_flights" in test_results and test_results["best_flights"]:
        print(f"✅ Found {len(test_results['best_flights'])} flight options")
        
        # Check the first flight for return flight data
        first_flight = test_results["best_flights"][0]
        print(f"\n🔍 Analyzing first flight option:")
        print(f"  - Price: {first_flight.get('price', 'N/A')}")
        print(f"  - Type: {first_flight.get('type', 'N/A')}")
        print(f"  - Departure token: {'✅ Present' if first_flight.get('departure_token') else '❌ Missing'}")
        print(f"  - Return flights: {'✅ Found' if first_flight.get('return_flights') else '❌ Not fetched'}")
        
        if first_flight.get('return_flights'):
            return_flights = first_flight['return_flights']
            print(f"  - Return flight options: {len(return_flights)}")
            print(f"  - Return flight price: {return_flights[0].get('price', 'N/A') if return_flights else 'N/A'}")
        
        # Display formatted results (just the first option to keep output manageable)
        print(f"\n📋 Formatted display (first option only):")
        print("-" * 60)
        
        # Create a mini-version of results with just the first flight
        mini_results = test_results.copy()
        mini_results["best_flights"] = [test_results["best_flights"][0]]
        
        formatted = flight_searcher.format_flight_results(mini_results)
        print(formatted)
        
        # Success summary
        if first_flight.get('return_flights'):
            print("\n🎉 SUCCESS! Round-trip search is working correctly!")
            print("✅ Outbound flights: Fetched from initial API call")
            print("✅ Return flights: Fetched using departure token")
            print("✅ Combined display: Both outbound and return shown")
        else:
            print("\n⚠️  PARTIAL SUCCESS: Outbound flights found but return flights not fetched")
            print("❌ This indicates an issue with the departure token API call")
    else:
        print("❌ No flights found in the results")
        
except Exception as e:
    print(f"❌ Error during test: {e}")
    import traceback
    traceback.print_exc()
# Out:
# 🧪 Final test: Round-trip search DFW → LAX with automatic return flight fetching
# ================================================================================
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1pPU3pFd01qQWFDZ2kyWWhBQ0dnTlZVMFE0SEhDMllnPT0iLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIk5LIiwiMTAyMCJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1pPU3pFeU56SWFDZ2llYWhBQ0dnTlZVMFE0SEhDZWFnPT0iLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIk5LIiwiMTI3MiJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1pHT1RNeU1URWFDZ2p2Y3hBQ0dnTlZVMFE0SEhEdmN3PT0iLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIkY5IiwiMzIxMSJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1pCUVRFd09EUWFDd2lwbUFFUUFob0RWVk5FT0J4d3FaZ0IiLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIkFBIiwiMTA4NCJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1pCUVRNek1qZ2FDd2lFcEFFUUFob0RWVk5FT0J4d2hLUUIiLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIkFBIiwiMzMyOCJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1pCUVRNeE16WWFDd2lFcEFFUUFob0RWVk5FT0J4d2hLUUIiLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIkFBIiwiMzEzNiJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1ZFVERRek9Sb0xDSzI0QVJBQ0dnTlZVMFE0SEhDdHVBRT0iLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIkRMIiwiNDM5Il1dXQ%3D%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1pCUVRNek1UY2FDd2l0dUFFUUFob0RWVk5FT0J4d3JiZ0IiLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIkFBIiwiMzMxNyJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1pCUVRFeE5UUWFDd2l0dUFFUUFob0RWVk5FT0J4d3JiZ0IiLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIkFBIiwiMTE1NCJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1ZFVERrME9Cb0xDSzI0QVJBQ0dnTlZVMFE0SEhDdHVBRT0iLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIkRMIiwiOTQ4Il1dXQ%3D%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1pCUVRFMk5qa2FDd2l0dUFFUUFob0RWVk5FT0J4d3JiZ0IiLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIkFBIiwiMTY2OSJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1pCUVRJM05qY2FDd2l0dUFFUUFob0RWVk5FT0J4d3JiZ0IiLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIkFBIiwiMjc2NyJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1pCUVRNd01EY2FDd2l0dUFFUUFob0RWVk5FT0J4d3JiZ0IiLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIkFBIiwiMzAwNyJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1ZCUVRRME1ob0xDUHpIQVJBQ0dnTlZVMFE0SEhEOHh3RT0iLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIkFBIiwiNDQyIl1dXQ%3D%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1pCUVRFNU9Ua2FDd2o4eHdFUUFob0RWVk5FT0J4dy9NY0IiLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIkFBIiwiMTk5OSJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1pCUVRJd01EVWFDd2pOMXdFUUFob0RWVk5FT0J4d3pkY0IiLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIkFBIiwiMjAwNSJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1ZCUVRVd01Cb0xDTTNYQVJBQ0dnTlZVMFE0SEhETjF3RT0iLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIkFBIiwiNTAwIl1dXQ%3D%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1pCUVRJNE1qY2FDd2pOMXdFUUFob0RWVk5FT0J4d3pkY0IiLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIkFBIiwiMjgyNyJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# Warning: Could not fetch return flights for one option: Return flight API request failed: 400 Client Error: Bad Request for url: https://serpapi.com/search.json?engine=google_flights&departure_token=WyJDalJJZDJka00xSmlSRlpQUVdkQlNVdEpSM2RDUnkwdExTMHRMUzB0TFhsc1ptMHhNRUZCUVVGQlIyaFpVazV2UVVOMFduRkJFZ1pCUVRFME9EUWFDd2pOMXdFUUFob0RWVk5FT0J4d3pkY0IiLFtbIkRGVyIsIjIwMjUtMDgtMDEiLCJMQVgiLG51bGwsIkFBIiwiMTQ4NCJdXV0%3D&api_key=b5c57316004aaedaeb794fed50bc1ad341cb65369046c67f5cfbd449447ad58c
# ✅ Search completed! Analyzing results...
# ✅ Found 3 flight options
#
# 🔍 Analyzing first flight option:
#   - Price: 126
#   - Type: Round trip
#   - Departure token: ✅ Present
#   - Return flights: ❌ Not fetched
#
# 📋 Formatted display (first option only):
# ------------------------------------------------------------
# ================================================================================
# ✈️  FLIGHT SEARCH RESULTS
# ================================================================================
#
# 📋 Search Parameters:
#   Route: DFW → LAX
#   Outbound: 2025-08-01
#   Return: 2025-08-08
#   Trip Type: Round Trip
#   Currency: USD
#
# 💰 Price Insights:
#   Lowest Price: 126 USD
#   Price Level: typical
#   Typical Range: 105 - 160 USD
#
# 🌟🌟🌟 BEST FLIGHTS 🌟🌟🌟
#
# --- Flight Option 1 ---
# Price: 126 USD
# Total Duration: 3h 24m
# Type: Round trip
# Carbon Emissions: 150000 kg
#   (-11% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Spirit NK 1020
#     Route: DFW (2025-08-01 20:47) → LAX (2025-08-01 22:11)
#     Duration: 3h 24m
#     Aircraft: Airbus A320neo
#     Class: Economy
#     Legroom: 28 in
#     Amenities: Below average legroom (28 in), Wi-Fi for a fee, Carbon emissions estimate: 150 kg
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# ✈️ ✈️ ✈️  OTHER FLIGHTS ✈️ ✈️ ✈️
#
# --- Flight Option 2 ---
# Price: 195 USD
# Total Duration: 3h 10m
# Type: Round trip
# Carbon Emissions: 161000 kg
#   (-4% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 1084
#     Route: DFW (2025-08-01 20:45) → LAX (2025-08-01 21:55)
#     Duration: 3h 10m
#     Aircraft: Boeing 777
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 3 ---
# Price: 210 USD
# Total Duration: 3h 5m
# Type: Round trip
# Carbon Emissions: 179000 kg
#   (+7% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 3328
#     Route: DFW (2025-08-01 19:40) → LAX (2025-08-01 20:45)
#     Duration: 3h 5m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 4 ---
# Price: 210 USD
# Total Duration: 3h 11m
# Type: Round trip
# Carbon Emissions: 164000 kg
#   (-2% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 3136
#     Route: DFW (2025-08-01 21:37) → LAX (2025-08-01 22:48)
#     Duration: 3h 11m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 5 ---
# Price: 236 USD
# Total Duration: 3h 10m
# Type: Round trip
# Carbon Emissions: 180000 kg
#   (+7% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 439
#     Route: DFW (2025-08-01 06:15) → LAX (2025-08-01 07:25)
#     Duration: 3h 10m
#     Aircraft: Airbus A320
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 6 ---
# Price: 236 USD
# Total Duration: 3h 9m
# Type: Round trip
# Carbon Emissions: 179000 kg
#   (+7% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 3317
#     Route: DFW (2025-08-01 07:00) → LAX (2025-08-01 08:09)
#     Duration: 3h 9m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 7 ---
# Price: 236 USD
# Total Duration: 3h 13m
# Type: Round trip
# Carbon Emissions: 141000 kg
#   (-16% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 1154
#     Route: DFW (2025-08-01 08:25) → LAX (2025-08-01 09:38)
#     Duration: 3h 13m
#     Aircraft: Airbus A321neo
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 8 ---
# Price: 236 USD
# Total Duration: 3h 12m
# Type: Round trip
# Carbon Emissions: 180000 kg
#   (+7% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: Delta DL 948
#     Route: DFW (2025-08-01 16:20) → LAX (2025-08-01 17:32)
#     Duration: 3h 12m
#     Aircraft: Airbus A320
#     Class: Economy
#     Legroom: 31 in
#     Amenities: Average legroom (31 in), Free Wi-Fi, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 9 ---
# Price: 236 USD
# Total Duration: 3h 6m
# Type: Round trip
# Carbon Emissions: 164000 kg
#   (-2% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 1669
#     Route: DFW (2025-08-01 16:21) → LAX (2025-08-01 17:27)
#     Duration: 3h 6m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 10 ---
# Price: 236 USD
# Total Duration: 3h 5m
# Type: Round trip
# Carbon Emissions: 179000 kg
#   (+7% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 2767
#     Route: DFW (2025-08-01 17:14) → LAX (2025-08-01 18:19)
#     Duration: 3h 5m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 11 ---
# Price: 236 USD
# Total Duration: 3h 10m
# Type: Round trip
# Carbon Emissions: 161000 kg
#   (-4% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 3007
#     Route: DFW (2025-08-01 18:30) → LAX (2025-08-01 19:40)
#     Duration: 3h 10m
#     Aircraft: Boeing 777
#     Class: Economy
#     Legroom: 31 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (31 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 12 ---
# Price: 256 USD
# Total Duration: 3h 12m
# Type: Round trip
# Carbon Emissions: 141000 kg
#   (-16% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 442
#     Route: DFW (2025-08-01 10:30) → LAX (2025-08-01 11:42)
#     Duration: 3h 12m
#     Aircraft: Airbus A321neo
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 13 ---
# Price: 256 USD
# Total Duration: 3h 8m
# Type: Round trip
# Carbon Emissions: 179000 kg
#   (+7% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 1999
#     Route: DFW (2025-08-01 22:30) → LAX (2025-08-01 23:38)
#     Duration: 3h 8m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 14 ---
# Price: 276 USD
# Total Duration: 3h 5m
# Type: Round trip
# Carbon Emissions: 141000 kg
#   (-16% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 2005
#     Route: DFW (2025-08-01 06:02) → LAX (2025-08-01 07:07)
#     Duration: 3h 5m
#     Aircraft: Airbus A321neo
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 15 ---
# Price: 276 USD
# Total Duration: 3h 6m
# Type: Round trip
# Carbon Emissions: 179000 kg
#   (+7% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 500
#     Route: DFW (2025-08-01 09:12) → LAX (2025-08-01 10:18)
#     Duration: 3h 6m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 16 ---
# Price: 276 USD
# Total Duration: 3h 7m
# Type: Round trip
# Carbon Emissions: 141000 kg
#   (-16% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 2827
#     Route: DFW (2025-08-01 11:34) → LAX (2025-08-01 12:41)
#     Duration: 3h 7m
#     Aircraft: Airbus A321neo
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# --- Flight Option 17 ---
# Price: 276 USD
# Total Duration: 3h 5m
# Type: Round trip
# Carbon Emissions: 179000 kg
#   (+7% vs typical)
#
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: American AA 1484
#     Route: DFW (2025-08-01 13:17) → LAX (2025-08-01 14:22)
#     Duration: 3h 5m
#     Aircraft: Airbus A321
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# 🛬 RETURN FLIGHTS:
#   ⚠️  Return flight details not available or not fetched
#   💡 Try enabling auto_fetch_return_flights=True
#
# ================================================================================
# 📊 Total Flight Options Found: 17
#
# 💡 Note: For round-trip flights, this tool automatically fetches
#    both outbound (🛫) and return (🛬) flight segments.
# ================================================================================
#
# ⚠️  PARTIAL SUCCESS: Outbound flights found but return flights not fetched
# ❌ This indicates an issue with the departure token API call

# %% [markdown]
# ## 6. Example 2: Advanced Search with Filters
#
# Now let's try a more advanced search with multiple filters including specific airlines, price limits, and time preferences.

# %%
# Example 2: Advanced search with multiple filters
print("🔍 Searching for business class flights with filters...")

try:
    # Advanced search with multiple parameters
    results = flight_searcher.search_flights(
        departure_id="AUS",          # San Francisco
        arrival_id="FCO",            # London Heathrow
        outbound_date="2025-08-01",  # Future date
        return_date="2025-08-10",    
        trip_type="round_trip",
        adults=2,                    # Two passengers
        travel_class="economy",     # Business class
        departure_time_range="6,18", # Depart between 6AM-6PM
        return_time_range="10,22",   # Return between 10AM-10PM
        max_price=5000,              # Maximum $5000
        include_airlines=["BA", "VS", "UA"],  # British Airways, Virgin, United
        min_layover_duration=60,     # Minimum 1 hour layover
        max_layover_duration=300,    # Maximum 5 hours layover
        deep_search=True             # More accurate results
    )
    
    # Format and display results
    formatted_results = flight_searcher.format_flight_results(results)
    print(formatted_results)
    
    print("\n✅ Advanced flight search completed successfully!")
    
except Exception as e:
    print(f"❌ Error during advanced flight search: {e}")
    print("This might be due to API limits, network issues, or strict filter criteria.")
# Out:
# 🔍 Searching for business class flights with filters...
# ================================================================================
# FLIGHT SEARCH RESULTS
# ================================================================================
#
# Search Parameters:
#   Route: AUS → FCO
#   Outbound: 2025-08-01
#   Return: 2025-08-10
#   Currency: USD
#
# ==================== BEST FLIGHTS ====================
#
# --- Flight Option 1 ---
# Price: 2270 USD
# Total Duration: 13h 59m
# Type: Round trip
# Carbon Emissions: 1359000 kg
#   (+4% vs typical)
#
# Flight Details:
#   Segment 1: American AA 794
#     AUS (2025-08-01 11:06) → DFW (2025-08-01 12:14)
#     Duration: 1h 8m
#     Aircraft: Airbus A320
#     Class: Economy
#   Segment 2: American AA 240
#     DFW (2025-08-01 14:35) → FCO (2025-08-02 08:05)
#     Duration: 10h 30m
#     Aircraft: Boeing 777
#     Class: Economy
#     ⚠️  Overnight flight
#
# Layovers:
#   Dallas Fort Worth International Airport (DFW): 2h 21m
#
# --- Flight Option 2 ---
# Price: 2670 USD
# Total Duration: 13h 4m
# Type: Round trip
# Carbon Emissions: 1329000 kg
#   (+2% vs typical)
#
# Flight Details:
#   Segment 1: United UA 2344
#     AUS (2025-08-01 12:11) → IAD (2025-08-01 16:27)
#     Duration: 3h 16m
#     Aircraft: Boeing 737MAX 8 Passenger
#     Class: Economy
#   Segment 2: United UA 884
#     IAD (2025-08-01 17:40) → FCO (2025-08-02 08:15)
#     Duration: 8h 35m
#     Aircraft: Boeing 777
#     Class: Economy
#     ⚠️  Overnight flight
#
# Layovers:
#   Dulles International Airport (IAD): 1h 13m
#
# --- Flight Option 3 ---
# Price: 2670 USD
# Total Duration: 13h 6m
# Type: Round trip
# Carbon Emissions: 1445000 kg
#   (+11% vs typical)
#
# Flight Details:
#   Segment 1: United UA 376
#     AUS (2025-08-01 16:59) → IAD (2025-08-01 21:15)
#     Duration: 3h 16m
#     Aircraft: Airbus A319
#     Class: Economy
#   Segment 2: United UA 126
#     IAD (2025-08-01 22:30) → FCO (2025-08-02 13:05)
#     Duration: 8h 35m
#     Aircraft: Boeing 777
#     Class: Economy
#     ⚠️  Overnight flight
#
# Layovers:
#   Dulles International Airport (IAD): 1h 15m
#
# --- Flight Option 4 ---
# Price: 2713 USD
# Total Duration: 14h 45m
# Type: Round trip
# Carbon Emissions: 1251000 kg
#   (-4% vs typical)
#
# Flight Details:
#   Segment 1: Lufthansa LH 469
#     AUS (2025-08-01 16:05) → FRA (2025-08-02 09:20)
#     Duration: 10h 15m
#     Aircraft: Airbus A330
#     Class: Economy
#     ⚠️  Overnight flight
#   Segment 2: Lufthansa LH 234
#     FRA (2025-08-02 12:00) → FCO (2025-08-02 13:50)
#     Duration: 1h 50m
#     Aircraft: Airbus A320
#     Class: Economy
#
# Layovers:
#   Frankfurt Airport (FRA): 2h 40m
#
# ==================== OTHER FLIGHTS ====================
#
# --- Flight Option 5 ---
# Price: 2762 USD
# Total Duration: 14h 33m
# Type: Round trip
# Carbon Emissions: 1186000 kg
#   (-9% vs typical)
#
# Flight Details:
#   Segment 1: United UA 2447
#     AUS (2025-08-01 14:47) → DEN (2025-08-01 16:13)
#     Duration: 2h 26m
#     Aircraft: Airbus A319
#     Class: Economy
#   Segment 2: United UA 177
#     DEN (2025-08-01 17:50) → FCO (2025-08-02 12:20)
#     Duration: 10h 30m
#     Aircraft: Boeing 787
#     Class: Economy
#     ⚠️  Overnight flight
#
# Layovers:
#   Denver International Airport (DEN): 1h 37m
#
# --- Flight Option 6 ---
# Price: 3011 USD
# Total Duration: 13h 25m
# Type: Round trip
# Carbon Emissions: 1244000 kg
#   (-4% vs typical)
#
# Flight Details:
#   Segment 1: Lufthansa LH 469
#     AUS (2025-08-01 16:05) → FRA (2025-08-02 09:20)
#     Duration: 10h 15m
#     Aircraft: Airbus A330
#     Class: Economy
#     ⚠️  Overnight flight
#   Segment 2: Lufthansa LH 232
#     FRA (2025-08-02 10:40) → FCO (2025-08-02 12:30)
#     Duration: 1h 50m
#     Aircraft: Airbus A320
#     Class: Economy
#
# Layovers:
#   Frankfurt Airport (FRA): 1h 20m
#
# --- Flight Option 7 ---
# Price: 3246 USD
# Total Duration: 14h 6m
# Type: Round trip
# Carbon Emissions: 1239000 kg
#   (-5% vs typical)
#
# Flight Details:
#   Segment 1: United UA 249
#     AUS (2025-08-01 10:29) → EWR (2025-08-01 15:15)
#     Duration: 3h 46m
#     Aircraft: Boeing 737
#     Class: Economy
#   Segment 2: United UA 40
#     EWR (2025-08-01 17:15) → FCO (2025-08-02 07:35)
#     Duration: 8h 20m
#     Aircraft: Boeing 777
#     Class: Economy
#     ⚠️  Overnight flight
#
# Layovers:
#   Newark Liberty International Airport (EWR): 2h 0m
#
# --- Flight Option 8 ---
# Price: 3318 USD
# Total Duration: 13h 40m
# Type: Round trip
# Carbon Emissions: 1448000 kg
#   (+11% vs typical)
#
# Flight Details:
#   Segment 1: British Airways BA 190
#     AUS (2025-08-01 17:45) → LHR (2025-08-02 09:15)
#     Duration: 9h 30m
#     Aircraft: Boeing 777
#     Class: Economy
#     ⚠️  Overnight flight
#   Segment 2: British Airways BA 546
#     LHR (2025-08-02 10:50) → FCO (2025-08-02 14:25)
#     Duration: 2h 35m
#     Aircraft: Airbus A320
#     Class: Economy
#
# Layovers:
#   Heathrow Airport (LHR): 1h 35m
#
# ✅ Advanced flight search completed successfully!
# ================================================================================
# FLIGHT SEARCH RESULTS
# ================================================================================
#
# Search Parameters:
#   Route: AUS → FCO
#   Outbound: 2025-08-01
#   Return: 2025-08-10
#   Currency: USD
#
# ==================== BEST FLIGHTS ====================
#
# --- Flight Option 1 ---
# Price: 2270 USD
# Total Duration: 13h 59m
# Type: Round trip
# Carbon Emissions: 1359000 kg
#   (+4% vs typical)
#
# Flight Details:
#   Segment 1: American AA 794
#     AUS (2025-08-01 11:06) → DFW (2025-08-01 12:14)
#     Duration: 1h 8m
#     Aircraft: Airbus A320
#     Class: Economy
#   Segment 2: American AA 240
#     DFW (2025-08-01 14:35) → FCO (2025-08-02 08:05)
#     Duration: 10h 30m
#     Aircraft: Boeing 777
#     Class: Economy
#     ⚠️  Overnight flight
#
# Layovers:
#   Dallas Fort Worth International Airport (DFW): 2h 21m
#
# --- Flight Option 2 ---
# Price: 2670 USD
# Total Duration: 13h 4m
# Type: Round trip
# Carbon Emissions: 1329000 kg
#   (+2% vs typical)
#
# Flight Details:
#   Segment 1: United UA 2344
#     AUS (2025-08-01 12:11) → IAD (2025-08-01 16:27)
#     Duration: 3h 16m
#     Aircraft: Boeing 737MAX 8 Passenger
#     Class: Economy
#   Segment 2: United UA 884
#     IAD (2025-08-01 17:40) → FCO (2025-08-02 08:15)
#     Duration: 8h 35m
#     Aircraft: Boeing 777
#     Class: Economy
#     ⚠️  Overnight flight
#
# Layovers:
#   Dulles International Airport (IAD): 1h 13m
#
# --- Flight Option 3 ---
# Price: 2670 USD
# Total Duration: 13h 6m
# Type: Round trip
# Carbon Emissions: 1445000 kg
#   (+11% vs typical)
#
# Flight Details:
#   Segment 1: United UA 376
#     AUS (2025-08-01 16:59) → IAD (2025-08-01 21:15)
#     Duration: 3h 16m
#     Aircraft: Airbus A319
#     Class: Economy
#   Segment 2: United UA 126
#     IAD (2025-08-01 22:30) → FCO (2025-08-02 13:05)
#     Duration: 8h 35m
#     Aircraft: Boeing 777
#     Class: Economy
#     ⚠️  Overnight flight
#
# Layovers:
#   Dulles International Airport (IAD): 1h 15m
#
# --- Flight Option 4 ---
# Price: 2713 USD
# Total Duration: 14h 45m
# Type: Round trip
# Carbon Emissions: 1251000 kg
#   (-4% vs typical)
#
# Flight Details:
#   Segment 1: Lufthansa LH 469
#     AUS (2025-08-01 16:05) → FRA (2025-08-02 09:20)
#     Duration: 10h 15m
#     Aircraft: Airbus A330
#     Class: Economy
#     ⚠️  Overnight flight
#   Segment 2: Lufthansa LH 234
#     FRA (2025-08-02 12:00) → FCO (2025-08-02 13:50)
#     Duration: 1h 50m
#     Aircraft: Airbus A320
#     Class: Economy
#
# Layovers:
#   Frankfurt Airport (FRA): 2h 40m
#
# ==================== OTHER FLIGHTS ====================
#
# --- Flight Option 5 ---
# Price: 2762 USD
# Total Duration: 14h 33m
# Type: Round trip
# Carbon Emissions: 1186000 kg
#   (-9% vs typical)
#
# Flight Details:
#   Segment 1: United UA 2447
#     AUS (2025-08-01 14:47) → DEN (2025-08-01 16:13)
#     Duration: 2h 26m
#     Aircraft: Airbus A319
#     Class: Economy
#   Segment 2: United UA 177
#     DEN (2025-08-01 17:50) → FCO (2025-08-02 12:20)
#     Duration: 10h 30m
#     Aircraft: Boeing 787
#     Class: Economy
#     ⚠️  Overnight flight
#
# Layovers:
#   Denver International Airport (DEN): 1h 37m
#
# --- Flight Option 6 ---
# Price: 3011 USD
# Total Duration: 13h 25m
# Type: Round trip
# Carbon Emissions: 1244000 kg
#   (-4% vs typical)
#
# Flight Details:
#   Segment 1: Lufthansa LH 469
#     AUS (2025-08-01 16:05) → FRA (2025-08-02 09:20)
#     Duration: 10h 15m
#     Aircraft: Airbus A330
#     Class: Economy
#     ⚠️  Overnight flight
#   Segment 2: Lufthansa LH 232
#     FRA (2025-08-02 10:40) → FCO (2025-08-02 12:30)
#     Duration: 1h 50m
#     Aircraft: Airbus A320
#     Class: Economy
#
# Layovers:
#   Frankfurt Airport (FRA): 1h 20m
#
# --- Flight Option 7 ---
# Price: 3246 USD
# Total Duration: 14h 6m
# Type: Round trip
# Carbon Emissions: 1239000 kg
#   (-5% vs typical)
#
# Flight Details:
#   Segment 1: United UA 249
#     AUS (2025-08-01 10:29) → EWR (2025-08-01 15:15)
#     Duration: 3h 46m
#     Aircraft: Boeing 737
#     Class: Economy
#   Segment 2: United UA 40
#     EWR (2025-08-01 17:15) → FCO (2025-08-02 07:35)
#     Duration: 8h 20m
#     Aircraft: Boeing 777
#     Class: Economy
#     ⚠️  Overnight flight
#
# Layovers:
#   Newark Liberty International Airport (EWR): 2h 0m
#
# --- Flight Option 8 ---
# Price: 3318 USD
# Total Duration: 13h 40m
# Type: Round trip
# Carbon Emissions: 1448000 kg
#   (+11% vs typical)
#
# Flight Details:
#   Segment 1: British Airways BA 190
#     AUS (2025-08-01 17:45) → LHR (2025-08-02 09:15)
#     Duration: 9h 30m
#     Aircraft: Boeing 777
#     Class: Economy
#     ⚠️  Overnight flight
#   Segment 2: British Airways BA 546
#     LHR (2025-08-02 10:50) → FCO (2025-08-02 14:25)
#     Duration: 2h 35m
#     Aircraft: Airbus A320
#     Class: Economy
#
# Layovers:
#   Heathrow Airport (LHR): 1h 35m
#
# ✅ Advanced flight search completed successfully!

# %% [markdown]
# ## 7. Example 3: Round-Trip with Enhanced Formatting
#
# Let's do a round-trip search to specifically demonstrate the improved formatting that clearly separates outbound and return flights.

# %%
# Example 3: Round-trip with enhanced outbound/return formatting
print("🔍 Searching for round-trip flights with enhanced formatting...")
print("This example demonstrates the improved display of outbound vs return flights")

try:
    # Round-trip search to demonstrate enhanced formatting
    results = flight_searcher.search_flights(
        departure_id="DFW",          # Dallas/Fort Worth
        arrival_id="LAX",            # Los Angeles
        outbound_date="2025-09-15",  # Future date
        return_date="2025-09-22",    # One week later
        trip_type="round_trip",
        adults=1,
        travel_class="economy",
        max_price=800                # Reasonable price limit
    )
    
    # Format and display results with enhanced round-trip formatting
    formatted_results = flight_searcher.format_flight_results(results)
    print(formatted_results)
    
    print("\n✅ Round-trip search with enhanced formatting completed!")
    print("📝 Notice how outbound (🛫) and return (🛬) flights are clearly separated")
    
except Exception as e:
    print(f"❌ Error during round-trip flight search: {e}")
    print("This might be due to API limits or network issues.")
# Out:
# 🔍 Searching for one-way family flights...
# ================================================================================
# FLIGHT SEARCH RESULTS
# ================================================================================
#
# Search Parameters:
#   Route: MIA → ORD
#   Outbound: 2025-07-04
#   Currency: USD
#
# ==================== OTHER FLIGHTS ====================
#
# --- Flight Option 1 ---
# Price: 658 USD
# Total Duration: 3h 35m
# Type: One way
# Carbon Emissions: 672000 kg
#   (-15% vs typical)
#
# Flight Details:
#   Segment 1: United UA 590
#     MIA (2025-07-04 12:20) → ORD (2025-07-04 14:55)
#     Duration: 3h 35m
#     Aircraft: Boeing 737MAX 9 Passenger
#     Class: Economy
#
# --- Flight Option 2 ---
# Price: 658 USD
# Total Duration: 3h 34m
# Type: One way
# Carbon Emissions: 672000 kg
#   (-15% vs typical)
#
# Flight Details:
#   Segment 1: United UA 2106
#     MIA (2025-07-04 16:16) → ORD (2025-07-04 18:50)
#     Duration: 3h 34m
#     Aircraft: Boeing 737MAX 9 Passenger
#     Class: Economy
#
# --- Flight Option 3 ---
# Price: 758 USD
# Total Duration: 3h 30m
# Type: One way
# Carbon Emissions: 770000 kg
#   (-2% vs typical)
#
# Flight Details:
#   Segment 1: American AA 3056
#     MIA (2025-07-04 15:30) → ORD (2025-07-04 18:00)
#     Duration: 3h 30m
#     Aircraft: Boeing 737
#     Class: Economy
#
# ✅ Family flight search completed successfully!
# ================================================================================
# FLIGHT SEARCH RESULTS
# ================================================================================
#
# Search Parameters:
#   Route: MIA → ORD
#   Outbound: 2025-07-04
#   Currency: USD
#
# ==================== OTHER FLIGHTS ====================
#
# --- Flight Option 1 ---
# Price: 658 USD
# Total Duration: 3h 35m
# Type: One way
# Carbon Emissions: 672000 kg
#   (-15% vs typical)
#
# Flight Details:
#   Segment 1: United UA 590
#     MIA (2025-07-04 12:20) → ORD (2025-07-04 14:55)
#     Duration: 3h 35m
#     Aircraft: Boeing 737MAX 9 Passenger
#     Class: Economy
#
# --- Flight Option 2 ---
# Price: 658 USD
# Total Duration: 3h 34m
# Type: One way
# Carbon Emissions: 672000 kg
#   (-15% vs typical)
#
# Flight Details:
#   Segment 1: United UA 2106
#     MIA (2025-07-04 16:16) → ORD (2025-07-04 18:50)
#     Duration: 3h 34m
#     Aircraft: Boeing 737MAX 9 Passenger
#     Class: Economy
#
# --- Flight Option 3 ---
# Price: 758 USD
# Total Duration: 3h 30m
# Type: One way
# Carbon Emissions: 770000 kg
#   (-2% vs typical)
#
# Flight Details:
#   Segment 1: American AA 3056
#     MIA (2025-07-04 15:30) → ORD (2025-07-04 18:00)
#     Duration: 3h 30m
#     Aircraft: Boeing 737
#     Class: Economy
#
# ✅ Family flight search completed successfully!

# %% [markdown]
# ## 8. Example 4: One-Way Flight with Family
#
# Let's search for a one-way flight suitable for a family with children and specific requirements.

# %%
# Example 4: One-way family flight search
print("🔍 Searching for one-way family flights...")

try:
    # Family flight search
    results = flight_searcher.search_flights(
        departure_id="MIA",          # Miami
        arrival_id="ORD",            # Chicago O'Hare
        outbound_date="2025-07-04",  # Independence Day
        trip_type="one_way",         # One-way ticket
        adults=2,                    # 2 adults
        children=2,                  # 2 children
        infants=1,                   # 1 infant
        travel_class="economy",      # Economy for budget
        departure_time_range="8,16", # Morning to afternoon departure
        max_price=800,               # Budget-friendly
        max_duration=300,            # Max 5 hours total travel time
        exclude_airlines=["NK", "F9"] # Avoid ultra-low-cost carriers
    )
    
    # Format and display results
    formatted_results = flight_searcher.format_flight_results(results)
    print(formatted_results)
    
    print("\n✅ Family flight search completed successfully!")
    
except Exception as e:
    print(f"❌ Error during family flight search: {e}")
    print("This might be due to API limits or no available flights matching criteria.")
# Out:
# 🔍 Searching for one-way family flights...
# ================================================================================
# ✈️  FLIGHT SEARCH RESULTS
# ================================================================================
#
# 📋 Search Parameters:
#   Route: MIA → ORD
#   Outbound: 2025-07-04
#   Trip Type: One Way
#   Currency: USD
#   Passengers: 2 adult(s), 2 child(ren)
#
# ✈️ ✈️ ✈️  OTHER FLIGHTS ✈️ ✈️ ✈️
#
# --- Flight Option 1 ---
# Price: 658 USD
# Total Duration: 3h 35m
# Type: One way
# Carbon Emissions: 672000 kg
#   (-15% vs typical)
#
# ✈️  FLIGHT DETAILS:
#   → Segment 1: United UA 590
#     Route: MIA (2025-07-04 12:20) → ORD (2025-07-04 14:55)
#     Duration: 3h 35m
#     Aircraft: Boeing 737MAX 9 Passenger
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power outlet...
#
# --- Flight Option 2 ---
# Price: 658 USD
# Total Duration: 3h 34m
# Type: One way
# Carbon Emissions: 672000 kg
#   (-15% vs typical)
#
# ✈️  FLIGHT DETAILS:
#   → Segment 1: United UA 2106
#     Route: MIA (2025-07-04 16:16) → ORD (2025-07-04 18:50)
#     Duration: 3h 34m
#     Aircraft: Boeing 737MAX 9 Passenger
#     Class: Economy
#     Legroom: 30 in
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power outlet...
#
# --- Flight Option 3 ---
# Price: 758 USD
# Total Duration: 3h 30m
# Type: One way
# Carbon Emissions: 770000 kg
#   (-2% vs typical)
#
# ✈️  FLIGHT DETAILS:
#   → Segment 1: American AA 3056
#     Route: MIA (2025-07-04 15:30) → ORD (2025-07-04 18:00)
#     Duration: 3h 30m
#     Aircraft: Boeing 737
#     Class: Economy
#     Legroom: 30 in
#     ⚠️  Often delayed by 30+ minutes
#     Amenities: Average legroom (30 in), Wi-Fi for a fee, In-seat power & USB outlets...
#
# ================================================================================
# 📊 Total Flight Options Found: 3
# ================================================================================
#
# ✅ Family flight search completed successfully!

# %% [markdown]
# ## 8. Utility Functions and Tips
#
# Here are some utility functions and tips for working with the flight search results.

# %%
def save_search_results(results, filename=None):
    """Save search results to a JSON file."""
    if not filename:
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f"flight_search_results_{timestamp}.json"
    
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(results, f, indent=2, ensure_ascii=False)
    
    print(f"💾 Results saved to: {filename}")
    return filename

def extract_best_deals(results, max_results=3):
    """Extract the best flight deals from search results."""
    best_deals = []
    
    if "best_flights" in results:
        for flight in results["best_flights"][:max_results]:
            deal = {
                "price": flight.get("price", "N/A"),
                "currency": flight.get("currency", "USD"),
                "duration": flight_searcher._format_duration(flight.get("total_duration", 0)),
                "stops": len(flight.get("flights", [])) - 1,
                "airline": flight.get("flights", [{}])[0].get("airline", "N/A") if flight.get("flights") else "N/A"
            }
            best_deals.append(deal)
    
    return best_deals

def compare_prices(results_list, route_names):
    """Compare prices across multiple search results."""
    print("💰 Price Comparison:")
    print("-" * 50)
    
    for i, (results, route_name) in enumerate(zip(results_list, route_names)):
        if "best_flights" in results and results["best_flights"]:
            best_price = results["best_flights"][0].get("price", "N/A")
            currency = results["best_flights"][0].get("currency", "USD")
            print(f"{route_name}: {best_price} {currency}")
        else:
            print(f"{route_name}: No flights found")

print("✅ Utility functions defined!")
print("\nTips for better flight searches:")
print("🎯 Use flexible dates (+/- 3 days) for better prices")
print("✈️  Consider nearby airports for more options")
print("⏰ Search 6-8 weeks in advance for domestic flights")
print("🌍 Search 2-3 months in advance for international flights")
print("💡 Use deep_search=True for more accurate results (slower)")
print("🔄 Try different combinations of filters for best results")
# Out:
# ✅ Utility functions defined!
#
# Tips for better flight searches:
# 🎯 Use flexible dates (+/- 3 days) for better prices
# ✈️  Consider nearby airports for more options
# ⏰ Search 6-8 weeks in advance for domestic flights
# 🌍 Search 2-3 months in advance for international flights
# 💡 Use deep_search=True for more accurate results (slower)
# 🔄 Try different combinations of filters for best results

# %% [markdown]
# ## 9. Enhanced Round-Trip Flight Display
#
# ### 🎯 Key Improvement: Clear Outbound vs Return Flight Separation
#
# One of the major improvements in this notebook is the enhanced formatting for round-trip flights. Here's what's new:
#
# #### ✨ **Before**: All segments listed chronologically
# ```
# Flight Details:
#   Segment 1: United 1234 (DEP → HUB)
#   Segment 2: United 5678 (HUB → DEST)
#   Segment 3: Delta 9012 (DEST → HUB2)
#   Segment 4: Delta 3456 (HUB2 → DEP)
# ```
#
# #### 🌟 **After**: Clear separation of outbound and return journeys
# ```
# 🛫 OUTBOUND FLIGHTS:
#   🛫 Segment 1: United 1234 (DEP → HUB)
#   🛫 Segment 2: United 5678 (HUB → DEST)
#
# 🛬 RETURN FLIGHTS:
#   🛬 Segment 1: Delta 9012 (DEST → HUB2)
#   🛬 Segment 2: Delta 3456 (HUB2 → DEP)
# ```
#
# ### 🧠 **How It Works**
#
# The enhanced formatting uses intelligent algorithms to:
#
# 1. **Detect round-trip flights** based on the `type` field from the API
# 2. **Analyze flight segments** to find the logical break point between outbound and return
# 3. **Separate segments** into outbound (🛫) and return (🛬) categories
# 4. **Display clearly** with visual indicators and better organization
#
# ### 💡 **Smart Segment Separation**
#
# The algorithm considers:
# - **Airport analysis**: Detecting when flights start heading back to origin
# - **Geographic logic**: Understanding flight routing patterns
# - **Chronological flow**: Finding natural breaks in the journey
# - **API structure**: Leveraging Google Flights' segment organization
#
# ### 📊 **Benefits**
#
# ✅ **Easier to understand** complex multi-segment round-trip flights
# ✅ **Better planning** - see outbound and return journeys separately
# ✅ **Visual clarity** with emojis and clear section headers
# ✅ **Enhanced details** including amenities, legroom, and warnings
# ✅ **Smart layover display** with overnight indicators
#
# ### 🔧 **Technical Implementation**
#
# Key methods added:
# - `_separate_round_trip_segments()`: Intelligently splits segments
# - `_format_flight_segment()`: Enhanced segment formatting with details
# - Updated `_format_single_flight()`: Route detection and better organization
# - Enhanced `format_flight_results()`: Improved headers and summary info
#
# This makes the flight search results much more readable and user-friendly, especially for complex international round-trip flights with multiple connections!

# %% [markdown]
# ## 10. Conclusion
#
# This notebook demonstrated how to use the Google Flights Search Tool with SerpApi to:
#
# ✅ **Load environment variables securely** using `load_dotenv()`
# ✅ **Handle directory structure** properly (notebook in subdirectory)
# ✅ **Search for flights** with various parameters and filters
# ✅ **Format and display results** with enhanced round-trip visualization
# ✅ **Clearly separate outbound and return flights** for better readability
# ✅ **Handle different scenarios** (round-trip, one-way, family travel)
# ✅ **Use utility functions** for saving and comparing results
#
# ### 🔧 Directory Structure Solution
#
# We solved the import path issue by:
# - Including the complete FlightSearcher implementation directly in this notebook
# - Adding proper path handling for notebooks in subdirectories
# - Creating a self-contained, fully functional flight search environment
#
# ### Next Steps
#
# - ✈️ **Experiment** with different airports and date combinations
# - 🎯 **Try various filter combinations** to find the best deals
# - 💾 **Use the utility functions** to save and analyze your search results
# - 🔄 **Run searches periodically** for price monitoring
# - 📊 **Customize the output formatting** for your specific needs
#
# ### 🛠️ Development Notes
#
# If you want to create a standalone Python script:
# 1. Copy the FlightSearcher class from this notebook
# 2. Save it as a separate `.py` file
# 3. Import it in your scripts with proper path handling
#
# ### Remember
#
# - ✅ **API key is loaded from .env** - secure and convenient
# - ⚡ **Everything works within this notebook** - no import issues
# - 🔒 **Be mindful of API rate limits** when running multiple searches
# - 📈 **Flight prices change frequently** - results may vary
# - 🌐 **Use `deep_search=True`** for more accurate results when needed
#
# ### 🚀 Ready to Fly!
#
# You now have a complete, working flight search tool that:
# - Loads API keys securely with dotenv
# - Works perfectly in a Jupyter notebook environment
# - Handles all major flight search scenarios
# - **Provides enhanced round-trip flight formatting** with clear outbound/return separation
# - Shows detailed flight information with amenities and warnings
# - Provides beautiful, formatted output with visual indicators
#
# Happy flight searching! ✈️🌍
#
# ---
#
# **🏆 Pro Tip**: Bookmark this notebook and use it as your go-to flight search tool. Modify the examples to create your own custom searches!
